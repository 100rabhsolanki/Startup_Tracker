# %% [markdown]
# # **Indian Start-Up Funding Analysis (2018-2021)**

# %% [markdown]
# Main Objective of the Project
#
# The primary objective of this project is to analyze the funding trends in the Indian start up ecosystem from 2018 to 2021. By examining the data, we aim to identify patterns, trends and insights that can inform strategic decisions for entering the Indian start up market. Specifically, we will focus on understanding the amount of funding received by start ups, the type of investors involved and the sectors that attract the most investment.

# %% [markdown]
# ### Hypothesis
#
# **Null Hypothesis (H₀):**
# There is no significant difference in the average funding amounts received across different sectors within the Indian startup ecosystem from 2018 to 2021.
#
# **Alternative Hypothesis (H₁):**
# There is a significant difference in the average funding amounts received across different sectors within the Indian startup ecosystem from 2018 to 2021.
#
# ---
#
# ### Key Research Questions
#
# 1. How has the total amount of funding received by start-ups in India changed from 2018 to 2021?
# 2. Which sectors have received the most funding in each year?
# 3. Who are the top investors in the Indian startup ecosystem from 2018 to 2021?
# 4. Which regions or cities in India are receiving the most startup funding?
# 5. What is the distribution of investment amounts across different stages of funding?
# 6. How are funding amounts distributed with respect to the number of investments?

# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns


warnings.filterwarnings('ignore')

# %%
import os
folder_path = r"C:\Users\saura\OneDrive\Desktop\N quant"

# List all CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# Load each CSV file into a DataFrame and store in a list
dataframes = []
for file in csv_files:
    full_path = os.path.join(folder_path, file)
    df = pd.read_csv(full_path)
    print(f"Loaded: {file} with shape {df.shape}")
    dataframes.append((file, df))

# %%
df_021 = pd.read_csv('data_2021_with_year.csv')  

print(df_021)
# Out:
#              Company  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics  2019.00   Bangalore             AI startup
# 1             upGrad  2015.00      Mumbai                 EdTech
# 2        Lead School  2012.00      Mumbai                 EdTech
# 3            Bizongo  2015.00      Mumbai         B2B E-commerce
# 4           FypMoney  2021.00    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce  2019.00    Gurugram  Staffing & Recruiting
# 1205          Vahdam  2015.00   New Delhi       Food & Beverages
# 1206    Leap Finance  2019.00   Bangalore     Financial Services
# 1207    CollegeDekho  2015.00    Gurugram                 EdTech
# 1208          WeRize  2019.00   Bangalore     Financial Services
#
#                                            What it does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# 2     LEAD School offers technology based school tra...
# 3     Bizongo is a business-to-business online marke...
# 4     FypMoney is Digital NEO Bank for Teenagers, em...
# ...                                                 ...
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                                                Founders  \
# 0                           Pramod Ghadge, Shahid Memon
# 1     Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                            Smita Deorah, Sumeet Mehta
# 3               Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                         Kapil Banwari
# ...                                                 ...
# 1204                        Chirag Mittal, Anirudh Syal
# 1205                                         Bala Sarda
# 1206                         Arnav Kumar, Vaibhav Singh
# 1207                                       Ruchir Arora
# 1208                      Vishal Chopra, Himanshu Gupta
#
#                                            Investor     Amount($)  \
# 0                       BEENEXT, Entrepreneur First    $1,200,000
# 1          Unilazer Ventures, IIFL Asset Management  $120,000,000
# 2                  GSV Ventures, Westbridge Capital   $30,000,000
# 3                            CDC Group, IDG Capital   $51,000,000
# 4     Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000
# ...                                             ...           ...
# 1204                                Endiya Partners      $3000000
# 1205                                       IIFL AMC     $20000000
# 1206                                   Owl Ventures     $55000000
# 1207               Winter Capital, ETS, Man Capital     $26000000
# 1208                 3one4 Capital, Kalaari Capital      $8000000
#
#              Stage  year
# 0     Pre-series A  2021
# 1              NaN  2021
# 2         Series D  2021
# 3         Series C  2021
# 4             Seed  2021
# ...            ...   ...
# 1204  Pre-series A  2021
# 1205      Series D  2021
# 1206      Series C  2021
# 1207      Series B  2021
# 1208      Series A  2021
#
# [1209 rows x 10 columns]

# %%
df_020 = pd.read_csv('data_2020_with_year.csv')  

print(df_020)
# Out:
#            Company  Founded HeadQuarter              Sector  \
# 0       Aqgromalin  2019.00     Chennai            AgriTech
# 1         Krayonnz  2019.00   Bangalore              EdTech
# 2     PadCare Labs  2018.00        Pune  Hygiene management
# 3            NCOME  2020.00   New Delhi              Escrow
# 4       Gramophone  2016.00      Indore            AgriTech
# ...            ...      ...         ...                 ...
# 1050  Leverage Edu      NaN       Delhi              Edtech
# 1051         EpiFi      NaN         NaN             Fintech
# 1052       Purplle  2012.00      Mumbai           Cosmetics
# 1053        Shuttl  2015.00       Delhi           Transport
# 1054         Pando  2017.00     Chennai            Logitech
#
#                                            What it does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# 3                          Escrow-as-a-service platform
# 4     Gramophone is an AgTech platform enabling acce...
# ...                                                 ...
# 1050  AI enabled marketplace that provides career gu...
# 1051  It offers customers with a single interface fo...
# 1052         Online makeup and beauty products retailer
# 1053                    App based bus aggregator serice
# 1054            Networked logistics management software
#
#                                                Founders  \
# 0                       Prasanna Manogaran, Bharani C L
# 1                      Saurabh Dixit, Gurudutt Upadhyay
# 2                                       Ajinkya Dhariya
# 3                                         Ritesh Tiwari
# 4     Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
# ...                                                 ...
# 1050                                  Akshay Chaturvedi
# 1051                    Sujith Narayanan, Sumit Gwalani
# 1052                          Manish Taneja, Rahul Dash
# 1053                      Amit Singh, Deepanshu Malviya
# 1054                     Jayakrishnan, Abhijeet Manohar
#
#                                    Investor   Amount($)       Stage column10  \
# 0                           Angel investors   200000.00         NaN      NaN
# 1                           GSF Accelerator   100000.00    Pre-seed      NaN
# 2                            Venture Center         NaN    Pre-seed      NaN
# 3       Venture Catalysts, PointOne Capital   400000.00         NaN      NaN
# 4       Siana Capital Management, Info Edge   340000.00         NaN      NaN
# ...                                     ...         ...         ...      ...
# 1050  DSG Consumer Partners, Blume Ventures  1500000.00         NaN      NaN
# 1051          Sequoia India, Ribbit Capital 13200000.00  Seed Round      NaN
# 1052                             Verlinvest  8000000.00         NaN      NaN
# 1053             SIG Global India Fund LLP.  8043000.00    Series C      NaN
# 1054                      Chiratae Ventures  9000000.00    Series A      NaN
#
#       year
# 0     2020
# 1     2020
# 2     2020
# 3     2020
# 4     2020
# ...    ...
# 1050  2020
# 1051  2020
# 1052  2020
# 1053  2020
# 1054  2020
#
# [1055 rows x 11 columns]

# %%
df_019 = pd.read_csv('data_2019_with_year.csv')  

print(df_019)
# Out:
#              Company  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics  2019.00   Bangalore             AI startup
# 1             upGrad  2015.00      Mumbai                 EdTech
# 2        Lead School  2012.00      Mumbai                 EdTech
# 3            Bizongo  2015.00      Mumbai         B2B E-commerce
# 4           FypMoney  2021.00    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce  2019.00    Gurugram  Staffing & Recruiting
# 1205          Vahdam  2015.00   New Delhi       Food & Beverages
# 1206    Leap Finance  2019.00   Bangalore     Financial Services
# 1207    CollegeDekho  2015.00    Gurugram                 EdTech
# 1208          WeRize  2019.00   Bangalore     Financial Services
#
#                                            What it does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# 2     LEAD School offers technology based school tra...
# 3     Bizongo is a business-to-business online marke...
# 4     FypMoney is Digital NEO Bank for Teenagers, em...
# ...                                                 ...
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                                                Founders  \
# 0                           Pramod Ghadge, Shahid Memon
# 1     Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                            Smita Deorah, Sumeet Mehta
# 3               Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                         Kapil Banwari
# ...                                                 ...
# 1204                        Chirag Mittal, Anirudh Syal
# 1205                                         Bala Sarda
# 1206                         Arnav Kumar, Vaibhav Singh
# 1207                                       Ruchir Arora
# 1208                      Vishal Chopra, Himanshu Gupta
#
#                                            Investor     Amount($)  \
# 0                       BEENEXT, Entrepreneur First    $1,200,000
# 1          Unilazer Ventures, IIFL Asset Management  $120,000,000
# 2                  GSV Ventures, Westbridge Capital   $30,000,000
# 3                            CDC Group, IDG Capital   $51,000,000
# 4     Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000
# ...                                             ...           ...
# 1204                                Endiya Partners      $3000000
# 1205                                       IIFL AMC     $20000000
# 1206                                   Owl Ventures     $55000000
# 1207               Winter Capital, ETS, Man Capital     $26000000
# 1208                 3one4 Capital, Kalaari Capital      $8000000
#
#              Stage  year
# 0     Pre-series A  2019
# 1              NaN  2019
# 2         Series D  2019
# 3         Series C  2019
# 4             Seed  2019
# ...            ...   ...
# 1204  Pre-series A  2019
# 1205      Series D  2019
# 1206      Series C  2019
# 1207      Series B  2019
# 1208      Series A  2019
#
# [1209 rows x 10 columns]

# %%
df_018 = pd.read_csv('data_2018_with_year.csv')  

print(df_018)
# Out:
#            Company  Founded HeadQuarter              Sector  \
# 0       Aqgromalin  2019.00     Chennai            AgriTech
# 1         Krayonnz  2019.00   Bangalore              EdTech
# 2     PadCare Labs  2018.00        Pune  Hygiene management
# 3            NCOME  2020.00   New Delhi              Escrow
# 4       Gramophone  2016.00      Indore            AgriTech
# ...            ...      ...         ...                 ...
# 1050  Leverage Edu      NaN       Delhi              Edtech
# 1051         EpiFi      NaN         NaN             Fintech
# 1052       Purplle  2012.00      Mumbai           Cosmetics
# 1053        Shuttl  2015.00       Delhi           Transport
# 1054         Pando  2017.00     Chennai            Logitech
#
#                                            What it does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# 3                          Escrow-as-a-service platform
# 4     Gramophone is an AgTech platform enabling acce...
# ...                                                 ...
# 1050  AI enabled marketplace that provides career gu...
# 1051  It offers customers with a single interface fo...
# 1052         Online makeup and beauty products retailer
# 1053                    App based bus aggregator serice
# 1054            Networked logistics management software
#
#                                                Founders  \
# 0                       Prasanna Manogaran, Bharani C L
# 1                      Saurabh Dixit, Gurudutt Upadhyay
# 2                                       Ajinkya Dhariya
# 3                                         Ritesh Tiwari
# 4     Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
# ...                                                 ...
# 1050                                  Akshay Chaturvedi
# 1051                    Sujith Narayanan, Sumit Gwalani
# 1052                          Manish Taneja, Rahul Dash
# 1053                      Amit Singh, Deepanshu Malviya
# 1054                     Jayakrishnan, Abhijeet Manohar
#
#                                    Investor   Amount($)       Stage column10  \
# 0                           Angel investors   200000.00         NaN      NaN
# 1                           GSF Accelerator   100000.00    Pre-seed      NaN
# 2                            Venture Center         NaN    Pre-seed      NaN
# 3       Venture Catalysts, PointOne Capital   400000.00         NaN      NaN
# 4       Siana Capital Management, Info Edge   340000.00         NaN      NaN
# ...                                     ...         ...         ...      ...
# 1050  DSG Consumer Partners, Blume Ventures  1500000.00         NaN      NaN
# 1051          Sequoia India, Ribbit Capital 13200000.00  Seed Round      NaN
# 1052                             Verlinvest  8000000.00         NaN      NaN
# 1053             SIG Global India Fund LLP.  8043000.00    Series C      NaN
# 1054                      Chiratae Ventures  9000000.00    Series A      NaN
#
#       year
# 0     2018
# 1     2018
# 2     2018
# 3     2018
# 4     2018
# ...    ...
# 1050  2018
# 1051  2018
# 1052  2018
# 1053  2018
# 1054  2018
#
# [1055 rows x 11 columns]

# %% [markdown]
#  #**Data Manipulation**

# %% [markdown]
# Renaming columns for consistency

# %%
# Rename columns for 2021 and 2020 datasets

df_021.rename(columns={
    'Company_Brand': 'Company',
    'What_it_does': 'What it does',
    'Amount': 'Amount($)'
}, inplace=True)

df_020.rename(columns={
    'Company_Brand': 'Company',
    'What_it_does': 'What it does',
    'Amount': 'Amount($)'
}, inplace=True)

# %%
# Rename columns for 2019 and 2018 datasets

df_019.rename(columns={
    'Company/Brand': 'Company'
}, inplace=True)

df_018.rename(columns={
    'Company Name': 'Company',
    'Industry': 'Sector',
    'Round/Series': 'Stage',
    'Amount': 'Amount($)',
    'Location': 'HeadQuarter',
    'About Company': 'What it does'
}, inplace=True)

# %% [markdown]
# Converting csv dataframs to csv files

# %%
# Save the DataFrames to CSV files
df_020.to_csv('data_2018.csv', index=False)
df_021.to_csv('data_2019.csv', index=False)
df_020.to_csv('data_2020.csv', index=False)
df_021.to_csv('data_2021.csv', index=False)

# %%
# Read the CSV files
df_018 = pd.read_csv('data_2020.csv')
df_019 = pd.read_csv('data_2021.csv')
df_020 = pd.read_csv('data_2020.csv')
df_021 = pd.read_csv('data_2021.csv')

# %% [markdown]
# Adding the year column to each csv file

# %%
# Add the "year" column to each DataFrame

df_018['year'] = 2018
df_019['year'] = 2019
df_020['year'] = 2020
df_021['year'] = 2021

# Save the modified DataFrames back to CSV files
df_018.to_csv('data_2018_with_year.csv', index=False)
df_019.to_csv('data_2019_with_year.csv', index=False)
df_020.to_csv('data_2020_with_year.csv', index=False)
df_021.to_csv('data_2021_with_year.csv', index=False)

# %%
# Define a fixed conversion rate for INR to USD
INR_TO_USD = 0.012


def convert_amount(amount):
    #Ensure amount is all string as the replace function does not apply on float objects

    # Check if the amount is already a float. If it is return it as it is.
    if isinstance(amount, float):
        return amount
    
    # Proceed to with amounts in string  form in order to apply replace function

    # Ensure the amount is a string and remove commas and whitespace
    amount_str = str(amount).replace(',', '').strip()
    
    try:
        # Check if the string starts with $ or ₹
        if amount_str.startswith('$'):
            return float(amount_str.replace('$', ''))
        elif amount_str.startswith('₹'):
            # Convert INR to USD using the fixed rate
            amount_inr = float(amount_str.replace('₹', ''))
            amount_usd = amount_inr * INR_TO_USD
            return amount_usd
        else:
            # Handle scientific notation and plain numbers
            return float(amount_str)
    except ValueError:
        # Handle any conversion errors (e.g., malformed strings)
        return None

# %%
# Apply conversion to the 'Amount($)' column for all datasets
df_018['Amount($)'] = df_018['Amount($)'].apply(convert_amount)
df_019['Amount($)'] = df_019['Amount($)'].apply(convert_amount)
df_020['Amount($)'] = df_020['Amount($)'].apply(convert_amount)
df_021['Amount($)'] = df_021['Amount($)'].apply(convert_amount)

# %%
# Concatenate the datasets

combined_df = pd.concat([df_018, df_019, df_020, df_021], ignore_index=True)

# Save the combined DataFrame to a CSV file
combined_df.to_csv('combined_data_with_years.csv', index=False)

# %%
combined_df.columns
# Out:
# Index(['Company', 'Founded', 'HeadQuarter', 'Sector', 'What it does',
#        'Founders', 'Investor', 'Amount($)', 'Stage', 'column10', 'year'],
#       dtype='object')

# %%
combined_df.head()
# Out:
#         Company  Founded HeadQuarter              Sector  \
# 0    Aqgromalin  2019.00     Chennai            AgriTech
# 1      Krayonnz  2019.00   Bangalore              EdTech
# 2  PadCare Labs  2018.00        Pune  Hygiene management
# 3         NCOME  2020.00   New Delhi              Escrow
# 4    Gramophone  2016.00      Indore            AgriTech
#
#                                         What it does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor  Amount($)     Stage column10  year
# 0                      Angel investors  200000.00       NaN      NaN  2018
# 1                      GSF Accelerator  100000.00  Pre-seed      NaN  2018
# 2                       Venture Center        NaN  Pre-seed      NaN  2018
# 3  Venture Catalysts, PointOne Capital  400000.00       NaN      NaN  2018
# 4  Siana Capital Management, Info Edge  340000.00       NaN      NaN  2018

# %%
combined_df.tail()
# Out:
#            Company  Founded HeadQuarter                 Sector  \
# 4523      Gigforce  2019.00    Gurugram  Staffing & Recruiting
# 4524        Vahdam  2015.00   New Delhi       Food & Beverages
# 4525  Leap Finance  2019.00   Bangalore     Financial Services
# 4526  CollegeDekho  2015.00    Gurugram                 EdTech
# 4527        WeRize  2019.00   Bangalore     Financial Services
#
#                                            What it does  \
# 4523                  A gig/on-demand staffing company.
# 4524  VAHDAM is among the world’s first vertically i...
# 4525  International education loans for high potenti...
# 4526  Collegedekho.com is Student’s Partner, Friend ...
# 4527  India’s first socially distributed full stack ...
#
#                            Founders                          Investor  \
# 4523    Chirag Mittal, Anirudh Syal                   Endiya Partners
# 4524                     Bala Sarda                          IIFL AMC
# 4525     Arnav Kumar, Vaibhav Singh                      Owl Ventures
# 4526                   Ruchir Arora  Winter Capital, ETS, Man Capital
# 4527  Vishal Chopra, Himanshu Gupta    3one4 Capital, Kalaari Capital
#
#        Amount($)         Stage column10  year
# 4523  3000000.00  Pre-series A      NaN  2021
# 4524 20000000.00      Series D      NaN  2021
# 4525 55000000.00      Series C      NaN  2021
# 4526 26000000.00      Series B      NaN  2021
# 4527  8000000.00      Series A      NaN  2021

# %% [markdown]
# ## **Exploratory Data Analysis**

# %%
# Determining the shape of the datasets

combined_df.shape
# Out:
# (4528, 11)

# %%
# Determining null values

print("Null values in combined_df:")
print(combined_df.isna().any())
# Out:
# Null values in combined_df:
# Company         False
# Founded          True
# HeadQuarter      True
# Sector           True
# What it does    False
# Founders         True
# Investor         True
# Amount($)        True
# Stage            True
# column10         True
# year            False
# dtype: bool

# %%
# Determining null values
print("Null values in combined_df:")
print(combined_df.isna().sum())
# Out:
# Null values in combined_df:
# Company            0
# Founded          428
# HeadQuarter      190
# Sector            26
# What it does       0
# Founders          32
# Investor         200
# Amount($)        814
# Stage           1784
# column10        4524
# year               0
# dtype: int64

# %%
#Gaining an overvew of the data
print("overvew of combined_df: ")
print(combined_df.info())
# Out:
# overvew of combined_df:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4528 entries, 0 to 4527
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       4528 non-null   object
#  1   Founded       4100 non-null   float64
#  2   HeadQuarter   4338 non-null   object
#  3   Sector        4502 non-null   object
#  4   What it does  4528 non-null   object
#  5   Founders      4496 non-null   object
#  6   Investor      4328 non-null   object
#  7   Amount($)     3714 non-null   float64
#  8   Stage         2744 non-null   object
#  9   column10      4 non-null      object
#  10  year          4528 non-null   int64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 389.3+ KB
# None

# %%
# Getting an overview with descriptive statistics

combined_df.describe(include = ['object']).T
# Out:
#              count unique                                                top  \
# Company       4528   1745                                           BharatPe
# HeadQuarter   4338    121                                          Bangalore
# Sector        4502    485                                            FinTech
# What it does  4528   2112  BYJU'S is an educational technology company th...
# Founders      4496   1919                   Ashneer Grover, Shashvat Nakrani
# Investor      4328   1712                          Inflection Point Ventures
# Stage         2744     58                                               Seed
# column10         4      2                                           Pre-Seed
#
#               freq
# Company         20
# HeadQuarter   1486
# Sector         346
# What it does    10
# Founders        14
# Investor        70
# Stage          652
# column10         2

# %%
# Determining unique values

combined_df.nunique()
# Out:
# Company         1745
# Founded           34
# HeadQuarter      121
# Sector           485
# What it does    2112
# Founders        1919
# Investor        1712
# Amount($)        394
# Stage             58
# column10           2
# year               4
# dtype: int64

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# Handling Missing Values

# %%
print("For combined_df: ")
print(combined_df.isnull().sum())
# Out:
# For combined_df:
# Company            0
# Founded          428
# HeadQuarter      190
# Sector            26
# What it does       0
# Founders          32
# Investor         200
# Amount($)        814
# Stage           1784
# column10        4524
# year               0
# dtype: int64

# %%
# Drop redundant columns

combined_df.drop(['column10'], axis = 1, inplace = True)

# %% [markdown]
# HeadQuarter Column

# %%
# Assuming 'Company' and 'Head Quarter' are separate columns in your DataFrame
# Iterating over both 'Company' and 'Head Quarter' columns

for index, row in combined_df.iterrows():
    company = row['Company']
    head_quarter = row['HeadQuarter']
    print(f"Index: {index}, Company: {company}, HeadQuarter: {head_quarter}")
# Out:
# Index: 0, Company: Aqgromalin, HeadQuarter: Chennai
# Index: 1, Company: Krayonnz, HeadQuarter: Bangalore
# Index: 2, Company: PadCare Labs, HeadQuarter: Pune
# Index: 3, Company: NCOME, HeadQuarter: New Delhi
# Index: 4, Company: Gramophone, HeadQuarter: Indore
# Index: 5, Company: qZense, HeadQuarter: Bangalore
# Index: 6, Company: MyClassboard, HeadQuarter: Hyderabad
# Index: 7, Company: Metvy, HeadQuarter: Gurgaon
# Index: 8, Company: Rupeek, HeadQuarter: Bangalore
# Index: 9, Company: Gig India, HeadQuarter: Pune
# Index: 10, Company: Slurrp Farm, HeadQuarter: Gurgaon
# Index: 11, Company: Medfin, HeadQuarter: Bangalore
# Index: 12, Company: MasterG, HeadQuarter: New Delhi
# Index: 13, Company: Brila 91, HeadQuarter: New Delhi
# Index: 14, Company: FoodyBuddy, HeadQuarter: Belgaum
# Index: 15, Company: Zomato, HeadQuarter: Gurgaon
# Index: 16, Company: OurEye.ai, HeadQuarter: Bangalore
# Index: 17, Company: Shiprocket, HeadQuarter: New Delhi
# Index: 18, Company: Pine Labs, HeadQuarter: Noida
# Index: 19, Company: Moneyboxx Finance, HeadQuarter: New Delhi
# Index: 20, Company: EWar, HeadQuarter: Bangalore
# Index: 21, Company: SucSEED Indovation, HeadQuarter: Hyderabad
# Index: 22, Company: TaxBuddy.com, HeadQuarter: Mumbai
# Index: 23, Company: Awign Enterprises, HeadQuarter: Bangalore
# Index: 24, Company: Circle of Angels, HeadQuarter: Gurgaon
# Index: 25, Company: CoinDCX, HeadQuarter: Mumbai
# Index: 26, Company: Glance, HeadQuarter: Bangalore
# Index: 27, Company: VerSe Innovation, HeadQuarter: Bangalore
# Index: 28, Company: Voosh, HeadQuarter: Bangalore
# Index: 29, Company: Delhivery, HeadQuarter: Gurgaon
# Index: 30, Company: Arya, HeadQuarter: Noida
# Index: 31, Company: Pickrr, HeadQuarter: New Delhi
# Index: 32, Company: PhonePe, HeadQuarter: Andheri
# Index: 33, Company: Countingwell, HeadQuarter: Bangalore
# Index: 34, Company: Callify.ai, HeadQuarter: Mumbai
# Index: 35, Company: Hudle, HeadQuarter: New Delhi
# Index: 36, Company: Cover it Up, HeadQuarter: Chennai
# Index: 37, Company: BiteSpeed, HeadQuarter: Gurgaon
# Index: 38, Company: WakeFit, HeadQuarter: Bangalore
# Index: 39, Company: Sreyas Holistic Remedies, HeadQuarter: Hyderabad
# Index: 40, Company: Fleeca India, HeadQuarter: Jaipur
# Index: 41, Company: M1xchange, HeadQuarter: Gurgaon
# Index: 42, Company: Exotel, HeadQuarter: Bangalore
# Index: 43, Company: PagarBook, HeadQuarter: Bangalore
# Index: 44, Company: PointOne Capital, HeadQuarter: Bangalore
# Index: 45, Company: Ayana, HeadQuarter: Bangalore
# Index: 46, Company: Fisdom, HeadQuarter: Bangalore
# Index: 47, Company: Tinker Coders, HeadQuarter: Noida
# Index: 48, Company: Infinite Uptime, HeadQuarter: Pune
# Index: 49, Company: HappyLocate, HeadQuarter: Bangalore
# Index: 50, Company: PhonePe, HeadQuarter: New Delhi
# Index: 51, Company: Loop Health, HeadQuarter: Pune
# Index: 52, Company: NeoDocs, HeadQuarter: Mumbai
# Index: 53, Company: The ePlane, HeadQuarter: Chennai
# Index: 54, Company: TagMango, HeadQuarter: Mumbai
# Index: 55, Company: The New Shop, HeadQuarter: New Delhi
# Index: 56, Company: MobiKwik, HeadQuarter: Gurgaon
# Index: 57, Company: DebugsBunny, HeadQuarter: Pune
# Index: 58, Company: BHIVE Investech, HeadQuarter: Bangalore
# Index: 59, Company: Rivigo, HeadQuarter: Gurgaon
# Index: 60, Company: ZipLoan, HeadQuarter: New Delhi
# Index: 61, Company: Swipez, HeadQuarter: Pune
# Index: 62, Company: Humus, HeadQuarter: Bangalore
# Index: 63, Company: Artivatic.ai, HeadQuarter: Bangalore
# Index: 64, Company: Prescinto, HeadQuarter: Ahmedabad
# Index: 65, Company: Toppeq, HeadQuarter: Mumbai
# Index: 66, Company: Bolo Indya, HeadQuarter: Gurgaon
# Index: 67, Company: Bombay Play, HeadQuarter: Bangalore
# Index: 68, Company: FreshToHome, HeadQuarter: Bangalore
# Index: 69, Company: KIKO TV, HeadQuarter: Mumbai
# Index: 70, Company: Atomberg Technologies, HeadQuarter: Mumbai
# Index: 71, Company: DealShare, HeadQuarter: Jaipur
# Index: 72, Company: Smallcase, HeadQuarter: Bangalore
# Index: 73, Company: CueMath, HeadQuarter: Bangalore
# Index: 74, Company: Gamerji, HeadQuarter: Ahmedabad
# Index: 75, Company: 5C Network, HeadQuarter: Bangalore
# Index: 76, Company: Ethereum Push Notification Service, HeadQuarter: Mumbai
# Index: 77, Company: Mihup, HeadQuarter: Kolkata
# Index: 78, Company: RuralBasket, HeadQuarter: Tirunelveli, Tamilnadu
# Index: 79, Company: WayCool Foods, HeadQuarter: Chennai
# Index: 80, Company: Infra.Market, HeadQuarter: Thane
# Index: 81, Company: Info Edge Venture, HeadQuarter: Noida
# Index: 82, Company: Clovia, HeadQuarter: Noida
# Index: 83, Company: Codingal, HeadQuarter: Bangalore
# Index: 84, Company: CRED, HeadQuarter: Bangalore
# Index: 85, Company: Vistaar Finance, HeadQuarter: Bangalore
# Index: 86, Company: Let's Dive, HeadQuarter: Bangalore
# Index: 87, Company: Habitat, HeadQuarter: nan
# Index: 88, Company: SAWO Labs, HeadQuarter: Mumbai
# Index: 89, Company: Signzy, HeadQuarter: Bangalore
# Index: 90, Company: KopyKitab, HeadQuarter: Bangalore
# Index: 91, Company: Kyt, HeadQuarter: Singapore
# Index: 92, Company: Raskik, HeadQuarter: nan
# Index: 93, Company: GetWork, HeadQuarter: Gurugram
# Index: 94, Company: Mobile Premier League (MPL), HeadQuarter: Bangalore
# Index: 95, Company: Pravasirojgar, HeadQuarter: nan
# Index: 96, Company: Omatra Hotels, HeadQuarter: Kolkata
# Index: 97, Company: Awign, HeadQuarter: Bangalore
# Index: 98, Company: NewsReach, HeadQuarter: Gujarat
# Index: 99, Company: Cashfree, HeadQuarter: Bangalore
# Index: 100, Company: Credgenics, HeadQuarter: New Delhi
# Index: 101, Company: GeoIQ, HeadQuarter: Bangalore
# Index: 102, Company: Country Delight, HeadQuarter: Haryana
# Index: 103, Company: Quintype, HeadQuarter: Bangalore
# Index: 104, Company: CARS24, HeadQuarter: Haryana
# Index: 105, Company: Astrogate Labs, HeadQuarter: Bangalore
# Index: 106, Company: Power Gummies, HeadQuarter: New Delhi
# Index: 107, Company: Cityflo, HeadQuarter: Mumbai
# Index: 108, Company: AlgoBulls, HeadQuarter: Mumbai
# Index: 109, Company: Credgenics, HeadQuarter: Gurugram
# Index: 110, Company: Inntot, HeadQuarter: Kerala
# Index: 111, Company: Ensuredit, HeadQuarter: Gurugram
# Index: 112, Company: Shipsy, HeadQuarter: Gurugram
# Index: 113, Company: ERPNext, HeadQuarter: Mumbai
# Index: 114, Company: LightSpeedAI, HeadQuarter: Bangalore
# Index: 115, Company: Grip Invest, HeadQuarter: Gurugram
# Index: 116, Company: Unacademy, HeadQuarter: Bangalore
# Index: 117, Company: Yellow Classes, HeadQuarter: Gurugram
# Index: 118, Company: Plum, HeadQuarter: Bangalore
# Index: 119, Company: STAGE, HeadQuarter: Indore
# Index: 120, Company: Nykaa, HeadQuarter: Mumbai
# Index: 121, Company: Kaagaz Scanner, HeadQuarter: nan
# Index: 122, Company: NIRA, HeadQuarter: Bangalore
# Index: 123, Company: Prolixr, HeadQuarter: Gurugram
# Index: 124, Company: Byju's, HeadQuarter: Bangalore
# Index: 125, Company: DaMENSCH, HeadQuarter: Bangalore
# Index: 126, Company: Country Delight, HeadQuarter: Haryana
# Index: 127, Company: SignalX, HeadQuarter: Hyderabad
# Index: 128, Company: Lancify, HeadQuarter: Bangalore
# Index: 129, Company: Krimanshi, HeadQuarter: Jodhpur
# Index: 130, Company: Instoried, HeadQuarter: Bangalore
# Index: 131, Company: PlayerzPot, HeadQuarter: Mumbai
# Index: 132, Company: Instamojo, HeadQuarter: Bangalore
# Index: 133, Company: Turtlemint, HeadQuarter: Mumbai
# Index: 134, Company: Arata, HeadQuarter: New Delhi
# Index: 135, Company: MPL, HeadQuarter: Bangalore
# Index: 136, Company: True Balance, HeadQuarter: Gurugram
# Index: 137, Company: Thrive, HeadQuarter: Mumbai
# Index: 138, Company: Kitchens Centre, HeadQuarter: New Delhi
# Index: 139, Company: Prescribe, HeadQuarter: Chennai
# Index: 140, Company: Nepra, HeadQuarter: Ahmedabad
# Index: 141, Company: inFeedo, HeadQuarter: Gurugram
# Index: 142, Company: Shilpa Sciences, HeadQuarter: Bangalore
# Index: 143, Company: Arzooo, HeadQuarter: Bangalore
# Index: 144, Company: MindTickle, HeadQuarter: Pune
# Index: 145, Company: Krimanshi, HeadQuarter: Jodhpur
# Index: 146, Company: Slice, HeadQuarter: Bangalore
# Index: 147, Company: Rapawalk, HeadQuarter: Bangalore
# Index: 148, Company: Oga Fit's, HeadQuarter: Bangalore
# Index: 149, Company: LAVAL, HeadQuarter: Bangalore
# Index: 150, Company: Stride Ventures, HeadQuarter: New Delhi
# Index: 151, Company: BlackSoil, HeadQuarter: Mumbai
# Index: 152, Company: Biocon, HeadQuarter: Bangalore
# Index: 153, Company: Clientjoy, HeadQuarter: Gujarat
# Index: 154, Company: Xpressbees, HeadQuarter: Pune
# Index: 155, Company: GalaxyCard, HeadQuarter: Gurugram
# Index: 156, Company: Wellness Forever, HeadQuarter: Mumbai
# Index: 157, Company: MoooFarm, HeadQuarter: Gurugram
# Index: 158, Company: BitClass, HeadQuarter: Bangalore
# Index: 159, Company: Gonuts, HeadQuarter: Mumbai
# Index: 160, Company: Uolo, HeadQuarter: Bangalore
# Index: 161, Company: Kirana King, HeadQuarter: Jaipur, Rajastan
# Index: 162, Company: Jade Forest, HeadQuarter: Delhi
# Index: 163, Company: iKure, HeadQuarter: Kolkata
# Index: 164, Company: FrontRow, HeadQuarter: Bangalore
# Index: 165, Company: Reliance Retail, HeadQuarter: Mumbai
# Index: 166, Company: TUBBR, HeadQuarter: Frisco, Texas, United States
# Index: 167, Company: Ather Energy, HeadQuarter: Bangalore
# Index: 168, Company: Routematic, HeadQuarter: Bangalore
# Index: 169, Company: LivFin, HeadQuarter: New Delhi
# Index: 170, Company: Universal Sportsbiz Pvt Ltd, HeadQuarter: Bangalore
# Index: 171, Company: Lattu Kids, HeadQuarter: Mumbai
# Index: 172, Company: Eggoz, HeadQuarter: Indore
# Index: 173, Company: Steradian Semiconductors, HeadQuarter: Bangalore
# Index: 174, Company: CHARGE+ZONE, HeadQuarter: Gujarat
# Index: 175, Company: Stones2milestones, HeadQuarter: Gurugram
# Index: 176, Company: Udacity, HeadQuarter: California
# Index: 177, Company: AjnaLens, HeadQuarter: Thane
# Index: 178, Company: Gully Network, HeadQuarter: Bangalore
# Index: 179, Company: TurboHire, HeadQuarter: Hyderabad
# Index: 180, Company: Traya, HeadQuarter: Mumbai
# Index: 181, Company: Charcoal Eats, HeadQuarter: Mumbai
# Index: 182, Company: Mitron TV, HeadQuarter: Bangalore
# Index: 183, Company: Svami, HeadQuarter: Mumbai
# Index: 184, Company: Dhurnia, HeadQuarter: Dhingsara, Haryana
# Index: 185, Company: Expertrons, HeadQuarter: Mumbai
# Index: 186, Company: Leena AI, HeadQuarter: New York, United States
# Index: 187, Company: Bizlog, HeadQuarter: Bangalore
# Index: 188, Company: Tamasha.live, HeadQuarter: Mumbai
# Index: 189, Company: Fedo, HeadQuarter: Bangalore
# Index: 190, Company: FabHotels, HeadQuarter: Gurugram
# Index: 191, Company: Freshokartz, HeadQuarter: Jaipur, Rajastan
# Index: 192, Company: FlexiLoans, HeadQuarter: Mumbai
# Index: 193, Company: Agrix, HeadQuarter: Patna
# Index: 194, Company: BharatAgri, HeadQuarter: Pune
# Index: 195, Company: FreshtoHome, HeadQuarter: Bangalore
# Index: 196, Company: Credable, HeadQuarter: Mumbai
# Index: 197, Company: Railofy, HeadQuarter: Mumbai
# Index: 198, Company: Finova Capital, HeadQuarter: Jaipur, Rajastan
# Index: 199, Company: Teachmint, HeadQuarter: Bangalore
# Index: 200, Company: Peel-Works, HeadQuarter: Mumbai
# Index: 201, Company: Janani, HeadQuarter: Bangalore
# Index: 202, Company: Credgenics, HeadQuarter: Gurugram
# Index: 203, Company: Finelistings, HeadQuarter: New Delhi
# Index: 204, Company: Wellversed, HeadQuarter: New Delhi
# Index: 205, Company: Nykaa, HeadQuarter: Mumbai
# Index: 206, Company: Jumbotail, HeadQuarter: Bangalore
# Index: 207, Company: Winzo, HeadQuarter: New Delhi
# Index: 208, Company: mCaffeine, HeadQuarter: Mumbai
# Index: 209, Company: Pocket FM, HeadQuarter: Bangalore
# Index: 210, Company: Snackible, HeadQuarter: Mumbai
# Index: 211, Company: FreshtoHome, HeadQuarter: Bangalore
# Index: 212, Company: Jumbotail, HeadQuarter: Bangalore
# Index: 213, Company: Nykaa, HeadQuarter: Mumbai
# Index: 214, Company: TagZ Foods, HeadQuarter: Bangalore
# Index: 215, Company: Genius Teacher, HeadQuarter: Mumbai
# Index: 216, Company: Krimanshi Feeds, HeadQuarter: Jodhpur
# Index: 217, Company: Origo, HeadQuarter: Gurugram
# Index: 218, Company: GetVantage, HeadQuarter: Mumbai
# Index: 219, Company: Betterplace, HeadQuarter: Bangalore
# Index: 220, Company: Biddano, HeadQuarter: Mumbai
# Index: 221, Company: InVideo, HeadQuarter: Mumbai
# Index: 222, Company: Arzooo, HeadQuarter: Bangalore
# Index: 223, Company: Hubilo, HeadQuarter: San Francisco, California, United States
# Index: 224, Company: BASIC Home Loan, HeadQuarter: Gurugram
# Index: 225, Company: Ketos, HeadQuarter: San Francisco, United States
# Index: 226, Company: SUGAR cosmetics, HeadQuarter: Mumbai
# Index: 227, Company: Signzy, HeadQuarter: Bangalore
# Index: 228, Company: Ahaguru, HeadQuarter: Chennai
# Index: 229, Company: Tekion, HeadQuarter: San Ramon, California
# Index: 230, Company: Brighteye Ventures, HeadQuarter: Paris, Ile-de-France, France
# Index: 231, Company: EzeRx, HeadQuarter: Kolkata
# Index: 232, Company: VitalTech, HeadQuarter: Plano, Texas, United States
# Index: 233, Company: Genius Teacher, HeadQuarter: Mumbai
# Index: 234, Company: Ultraviolette Automotive, HeadQuarter: Bangalore
# Index: 235, Company: Tring, HeadQuarter: Mumbai
# Index: 236, Company: Rare Planet, HeadQuarter: Kolkata
# Index: 237, Company: GoodGamer, HeadQuarter: Bangalore
# Index: 238, Company: InnAccel, HeadQuarter: Bangalore
# Index: 239, Company: Tiliter, HeadQuarter: Sydney
# Index: 240, Company: Slintel, HeadQuarter: San Francisco Bay Area, Silicon Valley, West Coast
# Index: 241, Company: SoOLEGAL, HeadQuarter: New Delhi
# Index: 242, Company: HobSpace, HeadQuarter: Mumbai
# Index: 243, Company: Supplynote, HeadQuarter: Noida
# Index: 244, Company: Hire Me Car, HeadQuarter: Noida
# Index: 245, Company: ShopUp, HeadQuarter: Bangaldesh
# Index: 246, Company: Harmonizer India, HeadQuarter: Bangalore
# Index: 247, Company: Zomato, HeadQuarter: Gurugram
# Index: 248, Company: Dukaan, HeadQuarter: Mumbai
# Index: 249, Company: CredR, HeadQuarter: Mumbai
# Index: 250, Company: Satyukt, HeadQuarter: Bangalore
# Index: 251, Company: RACEnergy, HeadQuarter: Hyderabad
# Index: 252, Company: TREAD, HeadQuarter: Bangalore
# Index: 253, Company: Anveshan, HeadQuarter: Bangalore
# Index: 254, Company: TeaMonk, HeadQuarter: Bangalore
# Index: 255, Company: Fleetx, HeadQuarter: Gurugram
# Index: 256, Company: ReNEWate, HeadQuarter: Pune
# Index: 257, Company: Tango Eye, HeadQuarter: Chennai
# Index: 258, Company: Rare Planet, HeadQuarter: Kolkata
# Index: 259, Company: Avataa Me, HeadQuarter: Bangalore
# Index: 260, Company: Arrival, HeadQuarter: London, England, United Kingdom
# Index: 261, Company: Cover Genius, HeadQuarter: Sydney, New South Wales, Australia
# Index: 262, Company: Phononic Vibes, HeadQuarter: Milano, Lombardia, Italy
# Index: 263, Company: MikeLegal, HeadQuarter: Gurugram
# Index: 264, Company: Clair, HeadQuarter: New York, United States
# Index: 265, Company: Gourmet Garden, HeadQuarter: Palmwoods, Queensland, Australia
# Index: 266, Company: Miko, HeadQuarter: Mumbai
# Index: 267, Company: Razorpay, HeadQuarter: Bangalore
# Index: 268, Company: Ninjacart, HeadQuarter: Bangalore
# Index: 269, Company: Wow! Momo, HeadQuarter: Kolkata
# Index: 270, Company: Pepper Content, HeadQuarter: Mumbai
# Index: 271, Company: LIVSPACE, HeadQuarter: Bangalore
# Index: 272, Company: Acculi Labs, HeadQuarter: Bangalore
# Index: 273, Company: Your MD, HeadQuarter: London, England, United Kingdom
# Index: 274, Company: Antaios, HeadQuarter: France
# Index: 275, Company: Unnati, HeadQuarter: Noida
# Index: 276, Company: Disprz, HeadQuarter: Chennai
# Index: 277, Company: Uni, HeadQuarter: Mumbai
# Index: 278, Company: Credit Wise Capital, HeadQuarter: Mumbai
# Index: 279, Company: Chargebee, HeadQuarter: San Francisco Bay Area, West Coast, Western US
# Index: 280, Company: Reliance Retail Ventures Ltd, HeadQuarter: Mumbai
# Index: 281, Company: Winuall, HeadQuarter: Bangalore
# Index: 282, Company: Genrobotics, HeadQuarter: Trivandrum, Kerala, India
# Index: 283, Company: Livve, HeadQuarter: Cochin
# Index: 284, Company: Ergos, HeadQuarter: Samastipur, Bihar
# Index: 285, Company: Krishitantra, HeadQuarter: Hyderabad
# Index: 286, Company: PakkaProfile, HeadQuarter: Bangalore
# Index: 287, Company: Monet Networks, HeadQuarter: Irvine, California, United States
# Index: 288, Company: Unocoin, HeadQuarter: Tumkur, Karnataka
# Index: 289, Company: Pesto, HeadQuarter: New Delhi
# Index: 290, Company: NirogStreet, HeadQuarter: Gurugram
# Index: 291, Company: Bambrew, HeadQuarter: Bangalore
# Index: 292, Company: Omnify, HeadQuarter: San Francisco Bay Area, Silicon Valley, West Coast
# Index: 293, Company: Fanball XI, HeadQuarter: New Delhi
# Index: 294, Company: Treebo Hotels, HeadQuarter: Bangalore
# Index: 295, Company: GPS Renewables, HeadQuarter: Bangalore
# Index: 296, Company: Public, HeadQuarter: New Delhi
# Index: 297, Company: Legal Salah, HeadQuarter: Kolkata
# Index: 298, Company: FanPlay, HeadQuarter: New Delhi
# Index: 299, Company: ECOSTP, HeadQuarter: Bangalore
# Index: 300, Company: Coralogix, HeadQuarter: San Francisco, California, United States
# Index: 301, Company: Equiwatt, HeadQuarter: Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom
# Index: 302, Company: Reliance Retail Ventures, HeadQuarter: Mumbai
# Index: 303, Company: Zhangmen, HeadQuarter: Shanghai, China
# Index: 304, Company: AgroWave, HeadQuarter: Gurugram
# Index: 305, Company: Sapio Analytics, HeadQuarter: Mumbai
# Index: 306, Company: Taimei, HeadQuarter: Jiaxing, Zhejiang, China
# Index: 307, Company: Avanse Financial Services, HeadQuarter: Mumbai
# Index: 308, Company: Industry Buying, HeadQuarter: New Delhi
# Index: 309, Company: Hopscotch, HeadQuarter: Mumbai
# Index: 310, Company: Pristyn Care, HeadQuarter: Gurugram
# Index: 311, Company: WoodenStreet, HeadQuarter: Rajastan
# Index: 312, Company: ACKO, HeadQuarter: Mumbai
# Index: 313, Company: Farmers Fresh Zone, HeadQuarter: Kochi
# Index: 314, Company: Invento, HeadQuarter: Bangalore
# Index: 315, Company: Infurnia, HeadQuarter: Bangalore
# Index: 316, Company: AnalytIQSports's SuperCric, HeadQuarter: Bangalore
# Index: 317, Company: Snowflake, HeadQuarter: California
# Index: 318, Company: GenieTalk, HeadQuarter: Indore
# Index: 319, Company: Classplus, HeadQuarter: Noida
# Index: 320, Company: Mobile Premier League, HeadQuarter: Bangalore
# Index: 321, Company: Fourth Partner Energy, HeadQuarter: Hyderabad
# Index: 322, Company: Flipkart, HeadQuarter: Bangalore
# Index: 323, Company: Vivriti Capital, HeadQuarter: Chennai
# Index: 324, Company: InsuranceDekho, HeadQuarter: Ludhiana
# Index: 325, Company: BestDoc, HeadQuarter: Kochi
# Index: 326, Company: Byju’s, HeadQuarter: Bangalore
# Index: 327, Company: Melorra, HeadQuarter: Bangalore
# Index: 328, Company: Reliance, HeadQuarter: Mumbai
# Index: 329, Company: Inflexor Ventures, HeadQuarter: Mumbai
# Index: 330, Company: Pandorum, HeadQuarter: Bangalore
# Index: 331, Company: SpeakIn, HeadQuarter: Noida
# Index: 332, Company: LetsUp, HeadQuarter: Mumbai
# Index: 333, Company: Newsreach, HeadQuarter: Gujarat
# Index: 334, Company: Dream11, HeadQuarter: Mumbai
# Index: 335, Company: SignalX, HeadQuarter: Hyderabad
# Index: 336, Company: JetSynthesys, HeadQuarter: Mumbai
# Index: 337, Company: Vesta Space Technology, HeadQuarter: Pune
# Index: 338, Company: Dozee, HeadQuarter: Bangalore
# Index: 339, Company: Rebel Foods, HeadQuarter: Pune
# Index: 340, Company: Nykaa, HeadQuarter: Mumbai
# Index: 341, Company: Ketto, HeadQuarter: Mumbai
# Index: 342, Company: Suryoday, HeadQuarter: Mumbai
# Index: 343, Company: SucSEED, HeadQuarter: Hyderabad
# Index: 344, Company: Unacademy, HeadQuarter: Bangalore
# Index: 345, Company: Strata, HeadQuarter: Bangalore
# Index: 346, Company: 3one4 Capital, HeadQuarter: Bangalore
# Index: 347, Company: WE-Hub, HeadQuarter: Hyderabad
# Index: 348, Company: Zomato, HeadQuarter: Haryana
# Index: 349, Company: Vicara, HeadQuarter: Bangalore
# Index: 350, Company: Gaana, HeadQuarter: Gurugram
# Index: 351, Company: EM3 Agri, HeadQuarter: Noida
# Index: 352, Company: Plum, HeadQuarter: Thane
# Index: 353, Company: Odwen, HeadQuarter: Noida
# Index: 354, Company: Fasal, HeadQuarter: Bangalore
# Index: 355, Company: Trukky, HeadQuarter: Ahmedabad
# Index: 356, Company: BankBazaar, HeadQuarter: Chennai
# Index: 357, Company: Specsmakers, HeadQuarter: Chennai
# Index: 358, Company: Grinntech, HeadQuarter: Dehradun
# Index: 359, Company: CreditMantri, HeadQuarter: Chennai
# Index: 360, Company: Chai Waale, HeadQuarter: Chennai
# Index: 361, Company: Deepsync, HeadQuarter: Bangalore
# Index: 362, Company: Byju’s, HeadQuarter: Bangalore
# Index: 363, Company: ConnectedH, HeadQuarter: Gurgaon
# Index: 364, Company: Reliance Retail, HeadQuarter: Mumbai
# Index: 365, Company: QShala, HeadQuarter: Bangalore
# Index: 366, Company: Pitstop, HeadQuarter: Bangalore
# Index: 367, Company: Zomato, HeadQuarter: Haryana
# Index: 368, Company: Customfit ai, HeadQuarter: Bangalore
# Index: 369, Company: Nirmata, HeadQuarter: San Franciscao
# Index: 370, Company: Hire Me Car, HeadQuarter: Noida
# Index: 371, Company: Oga Fit, HeadQuarter: Bangalore
# Index: 372, Company: ShipsKart, HeadQuarter: New Delhi
# Index: 373, Company: SquadStack, HeadQuarter: San Francisco
# Index: 374, Company: Financepeer, HeadQuarter: Mumbai
# Index: 375, Company: Cashify, HeadQuarter: Gurugram
# Index: 376, Company: Etrio, HeadQuarter: Hyderabad
# Index: 377, Company: Codeyoung, HeadQuarter: Bangalore
# Index: 378, Company: StayQrious, HeadQuarter: Bangalore
# Index: 379, Company: Sunstone Eduversity, HeadQuarter: Gurugram
# Index: 380, Company: Infilect, HeadQuarter: Bangalore
# Index: 381, Company: MobiGarage, HeadQuarter: New Delhi
# Index: 382, Company: Samunnati, HeadQuarter: Chennai
# Index: 383, Company: WeInnovate Biosolutions, HeadQuarter: Pune
# Index: 384, Company: Yummy Corp, HeadQuarter: Tangerang, Jawa Barat, Indonesia
# Index: 385, Company: Smallcase, HeadQuarter: Bangalore
# Index: 386, Company: Clairvolex, HeadQuarter: California
# Index: 387, Company: Assiduus, HeadQuarter: Bangalore
# Index: 388, Company: Brinton, HeadQuarter: California
# Index: 389, Company: AFK Gaming, HeadQuarter: Mumbai
# Index: 390, Company: Infarm, HeadQuarter: Berlin
# Index: 391, Company: Zuper, HeadQuarter: Seattle
# Index: 392, Company: mCaffeine, HeadQuarter: Mumbai
# Index: 393, Company: Origa, HeadQuarter: Andheri
# Index: 394, Company: GullyBuy Software, HeadQuarter: Pune
# Index: 395, Company: Recordent, HeadQuarter: Hyderabad
# Index: 396, Company: MPL, HeadQuarter: Bangalore
# Index: 397, Company: Penny, HeadQuarter: Riyadh
# Index: 398, Company: Onsitego, HeadQuarter: Mumbai
# Index: 399, Company: Precily, HeadQuarter: California
# Index: 400, Company: SmartClean, HeadQuarter: Singapore
# Index: 401, Company: ClanConnect, HeadQuarter: Delhi
# Index: 402, Company: Servify, HeadQuarter: Mumbai
# Index: 403, Company: ShareChat, HeadQuarter: Bangalore
# Index: 404, Company: Rephrase.ai, HeadQuarter: Bangalore
# Index: 405, Company: Melorra, HeadQuarter: Bangalore
# Index: 406, Company: FabHotels, HeadQuarter: Gurugram
# Index: 407, Company: EkAnek, HeadQuarter: New Delhi
# Index: 408, Company: Cub McPaws, HeadQuarter: Mumbai
# Index: 409, Company: Zimyo, HeadQuarter: Gurgaon
# Index: 410, Company: PumPumPum, HeadQuarter: Gurgaon
# Index: 411, Company: Burgerama, HeadQuarter: Gurgaon
# Index: 412, Company: Moms Co, HeadQuarter: Gurgaon
# Index: 413, Company: DillyHub, HeadQuarter: Seoul
# Index: 414, Company: FPL Technologies, HeadQuarter: Pune
# Index: 415, Company: FITTR, HeadQuarter: Pune
# Index: 416, Company: Illumnus, HeadQuarter: Pune
# Index: 417, Company: CashKaro, HeadQuarter: Gurgaon
# Index: 418, Company: Newton School, HeadQuarter: Bangalore
# Index: 419, Company: Airmeet, HeadQuarter: Bangalore
# Index: 420, Company: Observe ai, HeadQuarter: San Francisco
# Index: 421, Company: InCred, HeadQuarter: Mumbai
# Index: 422, Company: Toppr, HeadQuarter: Mumbai
# Index: 423, Company: CarTrade, HeadQuarter: Mumbai
# Index: 424, Company: LEAD School, HeadQuarter: Mumbai
# Index: 425, Company: Servify, HeadQuarter: Mumbai
# Index: 426, Company: Lido Learning, HeadQuarter: Mumbai
# Index: 427, Company: Apna.co, HeadQuarter: Bangalore
# Index: 428, Company: Quintype Technologies, HeadQuarter: Bangalore
# Index: 429, Company: Dunzo, HeadQuarter: Bangalore
# Index: 430, Company: Entropik, HeadQuarter: Bangalore
# Index: 431, Company: Livspace, HeadQuarter: Bangalore
# Index: 432, Company: Ultraviolette Automotive, HeadQuarter: Bangalore
# Index: 433, Company: WinZO, HeadQuarter: New Delhi
# Index: 434, Company: SenseHawk, HeadQuarter: Bangalore
# Index: 435, Company: Railofy, HeadQuarter: Mumbai
# Index: 436, Company: Eloelo, HeadQuarter: Bangalore
# Index: 437, Company: Aibono, HeadQuarter: Bangalore
# Index: 438, Company: BuildPan, HeadQuarter: Indore
# Index: 439, Company: Homelane, HeadQuarter: Bangalore
# Index: 440, Company: MyGlamm, HeadQuarter: Mumbai
# Index: 441, Company: Aviom, HeadQuarter: New Delhi
# Index: 442, Company: Flinto, HeadQuarter: Chennai
# Index: 443, Company: WayCool, HeadQuarter: Chennai
# Index: 444, Company: YAP, HeadQuarter: Chennai
# Index: 445, Company: Big Bang Boom Solutions, HeadQuarter: Chennai
# Index: 446, Company: GUVI, HeadQuarter: Chennai
# Index: 447, Company: BluSmart, HeadQuarter: Gurugram
# Index: 448, Company: Cell Propulsion, HeadQuarter: Bangalore
# Index: 449, Company: MPL, HeadQuarter: Bangalore
# Index: 450, Company: Spoonshot, HeadQuarter: Bangalore
# Index: 451, Company: Pulse, HeadQuarter: Mumbai
# Index: 452, Company: Groww, HeadQuarter: Bangalore
# Index: 453, Company: i3 Systems, HeadQuarter: Mumbai
# Index: 454, Company: SOAL, HeadQuarter: Mumbai
# Index: 455, Company: OckyPocky, HeadQuarter: Gurugram
# Index: 456, Company: Hippo Video, HeadQuarter: New York
# Index: 457, Company: Hasura, HeadQuarter: San Francisco
# Index: 458, Company: Qapita, HeadQuarter: Singapore
# Index: 459, Company: Sunday, HeadQuarter: Bangkok
# Index: 460, Company: Gamezop, HeadQuarter: Gurugram
# Index: 461, Company: Phool.co, HeadQuarter: Kanpur
# Index: 462, Company: Chiratae Ventures, HeadQuarter: Bangalore
# Index: 463, Company: MedLife, HeadQuarter: Bangalore
# Index: 464, Company: IDfy, HeadQuarter: Mumbai
# Index: 465, Company: True Balance, HeadQuarter: Gurugram
# Index: 466, Company: Bira91, HeadQuarter: New Delhi
# Index: 467, Company: Max wholesale, HeadQuarter: New Delhi
# Index: 468, Company: Craftsvilla, HeadQuarter: Mumbai
# Index: 469, Company: MechMocha, HeadQuarter: Bangalore
# Index: 470, Company: Mindhouse, HeadQuarter: Gurugram
# Index: 471, Company: DeepSync, HeadQuarter: Chandigarh
# Index: 472, Company: Eruditus, HeadQuarter: Mumbai
# Index: 473, Company: Gradeup, HeadQuarter: Noida
# Index: 474, Company: Tracxn, HeadQuarter: Bangalore
# Index: 475, Company: Purple Style Labs, HeadQuarter: Mumbai
# Index: 476, Company: ProPhysio, HeadQuarter: Bangalore
# Index: 477, Company: Flickstree, HeadQuarter: Mumbai
# Index: 478, Company: Settl, HeadQuarter: Gurugram
# Index: 479, Company: Fanspole, HeadQuarter: Thane
# Index: 480, Company: Sarva, HeadQuarter: Mumbai
# Index: 481, Company: Univ.ai, HeadQuarter: Bangalore
# Index: 482, Company: PurohitJi, HeadQuarter: Bangalore
# Index: 483, Company: CredoLab, HeadQuarter: Singapore
# Index: 484, Company: Brick&Bolt, HeadQuarter: Bangalore
# Index: 485, Company: Grinntech, HeadQuarter: Chennai
# Index: 486, Company: 6Degree, HeadQuarter: Mumbai
# Index: 487, Company: Exprs, HeadQuarter: nan
# Index: 488, Company: Bikayi, HeadQuarter: Hyderabad
# Index: 489, Company: Virtual Forest, HeadQuarter: Bangalore
# Index: 490, Company: The Health company, HeadQuarter: Gurugram
# Index: 491, Company: TrulyMadly Matchmakers, HeadQuarter: Gurugram
# Index: 492, Company: TrueFan, HeadQuarter: Mumbai
# Index: 493, Company: Fanspole, HeadQuarter: Mumbai
# Index: 494, Company: Byju's, HeadQuarter: Bangalore
# Index: 495, Company: Avail Finance, HeadQuarter: Bangalore
# Index: 496, Company: The Money Club, HeadQuarter: Delhi
# Index: 497, Company: Virohan, HeadQuarter: Gurgaon
# Index: 498, Company: OneCode, HeadQuarter: Gurugram
# Index: 499, Company: Verloop.io, HeadQuarter: nan
# Index: 500, Company: Otipy, HeadQuarter: nan
# Index: 501, Company: Evage, HeadQuarter: Chandigarh
# Index: 502, Company: LEAD School, HeadQuarter: Mumbai
# Index: 503, Company: Trell, HeadQuarter: Bangalore
# Index: 504, Company: Captain Fresh, HeadQuarter: Bangalore
# Index: 505, Company: Teachmint, HeadQuarter: Bangalore
# Index: 506, Company: Pixxel, HeadQuarter: Bangalore
# Index: 507, Company: Habbit Health, HeadQuarter: Delhi
# Index: 508, Company: SmarterBiz, HeadQuarter: Bangalore
# Index: 509, Company: Able Jobs, HeadQuarter: Bangalore
# Index: 510, Company: Vieroots, HeadQuarter: Kochi
# Index: 511, Company: Stack Finance, HeadQuarter: Bangalore
# Index: 512, Company: FPL Technologies, HeadQuarter: Pune
# Index: 513, Company: Masai School, HeadQuarter: Bangalore
# Index: 514, Company: Mitron, HeadQuarter: Bangalore
# Index: 515, Company: Daalchini, HeadQuarter: nan
# Index: 516, Company: Suno India, HeadQuarter: nan
# Index: 517, Company: LendingKart, HeadQuarter: Ahmedabad
# Index: 518, Company: Text Mercato, HeadQuarter: Bangalore
# Index: 519, Company: Eden Smart Homes, HeadQuarter: nan
# Index: 520, Company: GrayQuest, HeadQuarter: Mumbai
# Index: 521, Company: BigHaat, HeadQuarter: Bangalore
# Index: 522, Company: CityCash, HeadQuarter: Mumbai
# Index: 523, Company: HomeLane, HeadQuarter: Chennai
# Index: 524, Company: HungerBox, HeadQuarter: Bangalore
# Index: 525, Company: DaveAI, HeadQuarter: Bangalore
# Index: 526, Company: Eduvanz, HeadQuarter: Mumbai
# Index: 527, Company: ZipLoan, HeadQuarter: Delhi
# Index: 528, Company: DocSumo, HeadQuarter: Mumbai
# Index: 529, Company: CUSMAT, HeadQuarter: Warangal
# Index: 530, Company: Chingari, HeadQuarter: Bangalore
# Index: 531, Company: Bolo Indya, HeadQuarter: Gurugram
# Index: 532, Company: Data Sutram, HeadQuarter: Kolkata
# Index: 533, Company: Wobot Intelligence, HeadQuarter: Delhi
# Index: 534, Company: DrinkPrime, HeadQuarter: Bangalore
# Index: 535, Company: Infeedo, HeadQuarter: Gurugram
# Index: 536, Company: Probus Smart Things, HeadQuarter: Delhi
# Index: 537, Company: CrowdPouch, HeadQuarter: Bangalore
# Index: 538, Company: Rebel Foods, HeadQuarter: Mumbai
# Index: 539, Company: Hevo, HeadQuarter: Bangalore
# Index: 540, Company: BigSpoon Foods, HeadQuarter: Ahmedabad
# Index: 541, Company: Chingari, HeadQuarter: Bangalore
# Index: 542, Company: ShareChat, HeadQuarter: Bangalore
# Index: 543, Company: DatStop, HeadQuarter: Delhi
# Index: 544, Company: IPHM Services, HeadQuarter: Mumbai
# Index: 545, Company: Wellcure, HeadQuarter: Gurugram
# Index: 546, Company: VilCart, HeadQuarter: Bangalore
# Index: 547, Company: Firescore, HeadQuarter: Mumbai
# Index: 548, Company: BulBul, HeadQuarter: Gurgaon
# Index: 549, Company: Toppr, HeadQuarter: Mumbai
# Index: 550, Company: Pickright Technologies, HeadQuarter: Bangalore
# Index: 551, Company: Muse Wearables, HeadQuarter: Chennai
# Index: 552, Company: SATYA Microcapital, HeadQuarter: Delhi
# Index: 553, Company: WYN Studio, HeadQuarter: Gurugram
# Index: 554, Company: Fourth Partner Energy, HeadQuarter: Bangalore
# Index: 555, Company: Entri, HeadQuarter: Kochi
# Index: 556, Company: Snack Amor, HeadQuarter: Mumbai
# Index: 557, Company: MPowered, HeadQuarter: Gurugram
# Index: 558, Company: Leap Club, HeadQuarter: Gurugram
# Index: 559, Company: Ather Energy, HeadQuarter: Bangalore
# Index: 560, Company: Gigforce, HeadQuarter: Bangalore
# Index: 561, Company: Vegrow, HeadQuarter: Bangalore
# Index: 562, Company: Finn, HeadQuarter: Bangalore
# Index: 563, Company: Bijnis, HeadQuarter: nan
# Index: 564, Company: iNurture, HeadQuarter: Bangalore
# Index: 565, Company: StyleDotMe, HeadQuarter: Gurugram
# Index: 566, Company: Ripsey, HeadQuarter: Mumbai
# Index: 567, Company: ThriveFNC, HeadQuarter: Pune
# Index: 568, Company: Vedantu, HeadQuarter: Bangalore
# Index: 569, Company: Magicpin, HeadQuarter: Gurugram
# Index: 570, Company: Procol, HeadQuarter: Delhi
# Index: 571, Company: Yumlane, HeadQuarter: Mumbai
# Index: 572, Company: Crio, HeadQuarter: Bangalore
# Index: 573, Company: Openapp, HeadQuarter: Bangalore
# Index: 574, Company: PumPumPum, HeadQuarter: Gurugram
# Index: 575, Company: uFony Services Pvt ltd, HeadQuarter: Pune
# Index: 576, Company: Protinus Fashion Networking Pvt Ltd, HeadQuarter: Mumbai
# Index: 577, Company: Uable, HeadQuarter: Bangalore
# Index: 578, Company: ParkSmart, HeadQuarter: Delhi
# Index: 579, Company: Plum, HeadQuarter: Bangalore
# Index: 580, Company: IncNut Digital, HeadQuarter: Hyderabad
# Index: 581, Company: GigIndia, HeadQuarter: Pune
# Index: 582, Company: Specsmaker, HeadQuarter: Chennai
# Index: 583, Company: Piggy Ride, HeadQuarter: Bangalore
# Index: 584, Company: Chai Waale, HeadQuarter: Chennai
# Index: 585, Company: NOTO, HeadQuarter: Mumbai
# Index: 586, Company: Cuemath, HeadQuarter: Bangalore
# Index: 587, Company: Cars24, HeadQuarter: Gurgaon
# Index: 588, Company: JetSynthesys, HeadQuarter: Pune
# Index: 589, Company: Earth Energy EV, HeadQuarter: Mumbai
# Index: 590, Company: Green Cure, HeadQuarter: Delhi
# Index: 591, Company: Blue Sky Analytics, HeadQuarter: Gurugram
# Index: 592, Company: Edhusk, HeadQuarter: Jaipur
# Index: 593, Company: Decentro, HeadQuarter: Bangalore
# Index: 594, Company: Zolostays, HeadQuarter: Bangalore
# Index: 595, Company: Frontier Markets, HeadQuarter: Jaipur
# Index: 596, Company: Brainwired, HeadQuarter: Kerala
# Index: 597, Company: Aye Finance, HeadQuarter: Gurugram
# Index: 598, Company: Paper Boat, HeadQuarter: Gurugram
# Index: 599, Company: Ken42, HeadQuarter: Bangalore
# Index: 600, Company: Forbidden Foods, HeadQuarter: Delhi
# Index: 601, Company: Universal Sportsbiz, HeadQuarter: Bangalore
# Index: 602, Company: Gobbly, HeadQuarter: Gurugram
# Index: 603, Company: Aerostrovilos, HeadQuarter: Chennai
# Index: 604, Company: Mitron, HeadQuarter: Bangalore
# Index: 605, Company: Bulk MRO, HeadQuarter: Mumbai
# Index: 606, Company: Inspektlabs, HeadQuarter: Delhi
# Index: 607, Company: Big Bang Boom Solutions, HeadQuarter: Chennai
# Index: 608, Company: Flinto, HeadQuarter: Chennai
# Index: 609, Company: Zetwerk, HeadQuarter: Bangalore
# Index: 610, Company: ChitMonks, HeadQuarter: Hyderabad
# Index: 611, Company: Walrus, HeadQuarter: Bangalore
# Index: 612, Company: Arth Designbuild, HeadQuarter: Hyderebad
# Index: 613, Company: goDutch, HeadQuarter: Mumbai
# Index: 614, Company: Rusk Media, HeadQuarter: Delhi
# Index: 615, Company: Bold Care, HeadQuarter: Mumbai
# Index: 616, Company: Samosa Party, HeadQuarter: Bangalore
# Index: 617, Company: High Street Essentials, HeadQuarter: New Delhi
# Index: 618, Company: Byju's, HeadQuarter: Bangalore
# Index: 619, Company: Slice, HeadQuarter: Bangalore
# Index: 620, Company: Bombay Play, HeadQuarter: Bangalore
# Index: 621, Company: Fullife, HeadQuarter: Mumbai
# Index: 622, Company: Oziva, HeadQuarter: nan
# Index: 623, Company: Aye Finance, HeadQuarter: Gurugram
# Index: 624, Company: Aether Biomedical, HeadQuarter: Delhi
# Index: 625, Company: 91springboard, HeadQuarter: Delhi
# Index: 626, Company: Yulu, HeadQuarter: nan
# Index: 627, Company: Milkbasket, HeadQuarter: Gurugram
# Index: 628, Company: MergerDomo, HeadQuarter: Noida
# Index: 629, Company: GoMechanic, HeadQuarter: Delhi
# Index: 630, Company: Milk Mantra, HeadQuarter: Odisha
# Index: 631, Company: Myglamm, HeadQuarter: Mumbai
# Index: 632, Company: Drishti Technologies, HeadQuarter: Bangalore
# Index: 633, Company: Instasolv, HeadQuarter: Noida
# Index: 634, Company: GoldenPi, HeadQuarter: Bangalore
# Index: 635, Company: Peppermint, HeadQuarter: nan
# Index: 636, Company: Sarva, HeadQuarter: Mumbai
# Index: 637, Company: Jai Kisan, HeadQuarter: Mumbai
# Index: 638, Company: Agro2o, HeadQuarter: New Delhi
# Index: 639, Company: LetsTransport, HeadQuarter: Bangalore
# Index: 640, Company: GabbarDeals, HeadQuarter: Pune
# Index: 641, Company: Crimson Healthcare, HeadQuarter: Delhi
# Index: 642, Company: Biomoneta, HeadQuarter: Bangalore
# Index: 643, Company: Edvizo, HeadQuarter: Bangalore
# Index: 644, Company: Servify, HeadQuarter: Mumbai
# Index: 645, Company: Drum Food, HeadQuarter: Mumbai
# Index: 646, Company: Innoviti, HeadQuarter: Bangalore
# Index: 647, Company: Jiffy ai, HeadQuarter: nan
# Index: 648, Company: Postman, HeadQuarter: nan
# Index: 649, Company: F5, HeadQuarter: nan
# Index: 650, Company: Waycool, HeadQuarter: Chennai
# Index: 651, Company: Myelin Foundry, HeadQuarter: nan
# Index: 652, Company: Ameliorate Biotech, HeadQuarter: Bangalore
# Index: 653, Company: Hapramp, HeadQuarter: Gurugram
# Index: 654, Company: MyKaam, HeadQuarter: Bangalore
# Index: 655, Company: HealthPlix, HeadQuarter: Bangalore
# Index: 656, Company: YoloBus, HeadQuarter: Gurugram
# Index: 657, Company: iNurture Education, HeadQuarter: nan
# Index: 658, Company: Pocket52, HeadQuarter: Bangalore
# Index: 659, Company: QuaQua, HeadQuarter: Hyderabad
# Index: 660, Company: Crofarm, HeadQuarter: Delhi
# Index: 661, Company: Timios, HeadQuarter: Bangalore
# Index: 662, Company: Wooden Street, HeadQuarter: Jaipur
# Index: 663, Company: BankBazaar, HeadQuarter: Chennai
# Index: 664, Company: Rentmojo, HeadQuarter: Bangalore
# Index: 665, Company: Credgencies, HeadQuarter: nan
# Index: 666, Company: Knorish, HeadQuarter: Delhi
# Index: 667, Company: LetsTransport, HeadQuarter: Bangalore
# Index: 668, Company: Vahak, HeadQuarter: nan
# Index: 669, Company: Nutrova, HeadQuarter: Mumbai
# Index: 670, Company: Cube Wealth, HeadQuarter: Mumbai
# Index: 671, Company: IVF Access, HeadQuarter: Bangalore
# Index: 672, Company: Hoi Foods, HeadQuarter: Delhi
# Index: 673, Company: Ola Financial Services, HeadQuarter: Bangalore
# Index: 674, Company: Awifs, HeadQuarter: Delhi
# Index: 675, Company: Dunzo, HeadQuarter: Bangalore
# Index: 676, Company: Swiflearn, HeadQuarter: Gurugram
# Index: 677, Company: Remedo, HeadQuarter: Delhi
# Index: 678, Company: Blowhorn, HeadQuarter: Bangalore
# Index: 679, Company: Toch, HeadQuarter: Mumbai
# Index: 680, Company: Gram Cover, HeadQuarter: Noida
# Index: 681, Company: Coin DCX, HeadQuarter: Mumbai
# Index: 682, Company: HomeCapital, HeadQuarter: Mumbai
# Index: 683, Company: Euler Motors, HeadQuarter: Delhi
# Index: 684, Company: Riskcovry, HeadQuarter: Mumbai
# Index: 685, Company: NWNT (No Worry No Tension Healthcare), HeadQuarter: Delhi
# Index: 686, Company: Voicezen, HeadQuarter: Gurugram
# Index: 687, Company: Leap Club, HeadQuarter: Gurugram
# Index: 688, Company: Credit Mantri, HeadQuarter: Chennai
# Index: 689, Company: Xtracap, HeadQuarter: Gurugram
# Index: 690, Company: Tring, HeadQuarter: Mumbai
# Index: 691, Company: Vakilsearch, HeadQuarter: Chennai
# Index: 692, Company: Khatabook, HeadQuarter: Bangalore
# Index: 693, Company: LendingKart, HeadQuarter: Ahmedabad
# Index: 694, Company: Illumnus, HeadQuarter: nan
# Index: 695, Company: LetsTransport, HeadQuarter: Bangalore
# Index: 696, Company: Eggoz, HeadQuarter: Bihar
# Index: 697, Company: Winuall, HeadQuarter: Bangalore
# Index: 698, Company: Indian School Finance Company, HeadQuarter: Hyderabad
# Index: 699, Company: Juicy Chemistry, HeadQuarter: nan
# Index: 700, Company: DeepTek, HeadQuarter: Pune
# Index: 701, Company: Stepathlon Lifestyle, HeadQuarter: Mumbai
# Index: 702, Company: Sindhuja Microcredit, HeadQuarter: Noida
# Index: 703, Company: Rentmojo, HeadQuarter: Bangalore
# Index: 704, Company: Tesco Charge Zone, HeadQuarter: Gujarat
# Index: 705, Company: Intello Labs, HeadQuarter: Gurugram
# Index: 706, Company: SirionLabs, HeadQuarter: Gurugram
# Index: 707, Company: Magicpin, HeadQuarter: Gurugram
# Index: 708, Company: GroCurv, HeadQuarter: Gurugram
# Index: 709, Company: Refrens, HeadQuarter: Bangalore
# Index: 710, Company: Shiprocket, HeadQuarter: nan
# Index: 711, Company: Spyne, HeadQuarter: Gurugram
# Index: 712, Company: Nykaa, HeadQuarter: Mumbai
# Index: 713, Company: Docsapp, HeadQuarter: Bangalore
# Index: 714, Company: Phable, HeadQuarter: nan
# Index: 715, Company: Generic Aadhaar, HeadQuarter: nan
# Index: 716, Company: Nium, HeadQuarter: nan
# Index: 717, Company: Mintoak, HeadQuarter: Mumbai
# Index: 718, Company: VestSpace, HeadQuarter: Pune
# Index: 719, Company: Blackbuck, HeadQuarter: Bangalore
# Index: 720, Company: Vernacular ai, HeadQuarter: Bangalore
# Index: 721, Company: Clover, HeadQuarter: Bangalore
# Index: 722, Company: Varthana, HeadQuarter: Bangalore
# Index: 723, Company: Codeninja, HeadQuarter: Bangalore
# Index: 724, Company: MetaMerphoSys, HeadQuarter: Pune
# Index: 725, Company: Rooter, HeadQuarter: Delhi
# Index: 726, Company: Aker Foods, HeadQuarter: Pune
# Index: 727, Company: Sascan Meditech pvt ltd, HeadQuarter: Kerala
# Index: 728, Company: DailyHunt, HeadQuarter: nan
# Index: 729, Company: Pratilipi, HeadQuarter: Bangalore
# Index: 730, Company: Biryani By Kilo, HeadQuarter: Delhi
# Index: 731, Company: Consure Medical, HeadQuarter: Delhi
# Index: 732, Company: Servify, HeadQuarter: Mumbai
# Index: 733, Company: Tessol, HeadQuarter: Mumbai
# Index: 734, Company: Remedo, HeadQuarter: Noida
# Index: 735, Company: News Reach, HeadQuarter: Ahmedabad
# Index: 736, Company: RoomSoom, HeadQuarter: Noida
# Index: 737, Company: Pedagogy, HeadQuarter: nan
# Index: 738, Company: Classplus, HeadQuarter: Delhi
# Index: 739, Company: Medlife, HeadQuarter: Bangalore
# Index: 740, Company: Qin1, HeadQuarter: Noida
# Index: 741, Company: MYSUN, HeadQuarter: Delhi
# Index: 742, Company: ShopX, HeadQuarter: Bangalore
# Index: 743, Company: Sarva, HeadQuarter: nan
# Index: 744, Company: Expertrons, HeadQuarter: Mumbai
# Index: 745, Company: NewsBytes, HeadQuarter: Gurugram
# Index: 746, Company: Wagonfly, HeadQuarter: Bangalore
# Index: 747, Company: NIRA, HeadQuarter: nan
# Index: 748, Company: Convosight, HeadQuarter: Hyderabad
# Index: 749, Company: Fittr, HeadQuarter: Pune
# Index: 750, Company: AsknBid, HeadQuarter: Bangalore
# Index: 751, Company: Bira91, HeadQuarter: Bangalore
# Index: 752, Company: Finaureus Technologies, HeadQuarter: Pune
# Index: 753, Company: Daily Ninja, HeadQuarter: Haryana
# Index: 754, Company: Guvi Geek Network Pvt Ltd, HeadQuarter: Chennai
# Index: 755, Company: LoadShare, HeadQuarter: Bangalore
# Index: 756, Company: Vedantu, HeadQuarter: Bangalore
# Index: 757, Company: Indusface, HeadQuarter: nan
# Index: 758, Company: DMI Group, HeadQuarter: Delhi
# Index: 759, Company: Spintly, HeadQuarter: Goa
# Index: 760, Company: Credr, HeadQuarter: Mumbai
# Index: 761, Company: Bijak, HeadQuarter: Gurugram
# Index: 762, Company: Bugworks, HeadQuarter: Bangalore
# Index: 763, Company: DrinkPrime, HeadQuarter: Bangalore
# Index: 764, Company: Yap, HeadQuarter: Chennai
# Index: 765, Company: UzhavarBumi, HeadQuarter: Tamil Nadu
# Index: 766, Company: Tattva, HeadQuarter: Delhi
# Index: 767, Company: Pariksha, HeadQuarter: Pune
# Index: 768, Company: DailyHunt, HeadQuarter: nan
# Index: 769, Company: NoBroker, HeadQuarter: Bangalore
# Index: 770, Company: Box8, HeadQuarter: Mumbai
# Index: 771, Company: Capital Float, HeadQuarter: Bangalore
# Index: 772, Company: ITILITE, HeadQuarter: Bangalore
# Index: 773, Company: Morning Context, HeadQuarter: nan
# Index: 774, Company: Aavenir, HeadQuarter: Ahmedabad
# Index: 775, Company: Savvy Co op, HeadQuarter: nan
# Index: 776, Company: BLive, HeadQuarter: nan
# Index: 777, Company: Yellow Messenger, HeadQuarter: Bangalore
# Index: 778, Company: Toch, HeadQuarter: nan
# Index: 779, Company: Ewar, HeadQuarter: Bangalore
# Index: 780, Company: Setu, HeadQuarter: nan
# Index: 781, Company: Wellthy Therapeutics, HeadQuarter: Bangalore
# Index: 782, Company: Power Gummies, HeadQuarter: Delhi
# Index: 783, Company: Locale ai, HeadQuarter: Bangalore
# Index: 784, Company: FarEye, HeadQuarter: Delhi
# Index: 785, Company: Rebel Foods, HeadQuarter: nan
# Index: 786, Company: BankBazaar, HeadQuarter: Chennai
# Index: 787, Company: Porter, HeadQuarter: Mumbai
# Index: 788, Company: SugarBox, HeadQuarter: Mumbai
# Index: 789, Company: Capital Float, HeadQuarter: Bangalore
# Index: 790, Company: Big Basket, HeadQuarter: Bangalore
# Index: 791, Company: Amica, HeadQuarter: nan
# Index: 792, Company: Vedantu, HeadQuarter: Bangalore
# Index: 793, Company: Fingerlix, HeadQuarter: nan
# Index: 794, Company: Plop, HeadQuarter: Mumbai
# Index: 795, Company: Zupee, HeadQuarter: nan
# Index: 796, Company: DeHaat, HeadQuarter: nan
# Index: 797, Company: Lido Learning, HeadQuarter: Mumbai
# Index: 798, Company: Aye Finance, HeadQuarter: Gurugram
# Index: 799, Company: Swiggy, HeadQuarter: Bangalore
# Index: 800, Company: Akna Medical, HeadQuarter: nan
# Index: 801, Company: Zomato, HeadQuarter: Gurugram
# Index: 802, Company: RaRa Delivery, HeadQuarter: nan
# Index: 803, Company: JusPay, HeadQuarter: Bangalore
# Index: 804, Company: Obviously AI, HeadQuarter: nan
# Index: 805, Company: Fingpay, HeadQuarter: Mumbai
# Index: 806, Company: Recko, HeadQuarter: Bangalore
# Index: 807, Company: Furlenco, HeadQuarter: Bangalore
# Index: 808, Company: Mera Cashier, HeadQuarter: Noida
# Index: 809, Company: Kitchens Centre, HeadQuarter: Delhi
# Index: 810, Company: Camp K12, HeadQuarter: Gurugram
# Index: 811, Company: MedGenome, HeadQuarter: Bangalore
# Index: 812, Company: Ergos, HeadQuarter: Bangalore
# Index: 813, Company: Nykaa, HeadQuarter: Mumbai
# Index: 814, Company: Samadhan, HeadQuarter: Delhi
# Index: 815, Company: SaScan, HeadQuarter: Bangalore
# Index: 816, Company: Lido Learning, HeadQuarter: Mumbai
# Index: 817, Company: CureFit, HeadQuarter: Bangalore
# Index: 818, Company: Nimesa, HeadQuarter: Bangalore
# Index: 819, Company: Design X, HeadQuarter: Noida
# Index: 820, Company: Driftly Electric, HeadQuarter: Bangalore
# Index: 821, Company: Imstrong, HeadQuarter: Bangalore
# Index: 822, Company: Craftsvilla, HeadQuarter: Mumbai
# Index: 823, Company: Rupifi, HeadQuarter: Bangalore
# Index: 824, Company: SnackAmor, HeadQuarter: Mumbai
# Index: 825, Company: Zealthy, HeadQuarter: Bangalore
# Index: 826, Company: CoinDCX, HeadQuarter: nan
# Index: 827, Company: NuNu TV, HeadQuarter: nan
# Index: 828, Company: QTalk, HeadQuarter: Bangalore
# Index: 829, Company: Shadez, HeadQuarter: Mumbai
# Index: 830, Company: Excess2Sell, HeadQuarter: Mumbai
# Index: 831, Company: Stanplus, HeadQuarter: Hyderabad
# Index: 832, Company: Pitstop, HeadQuarter: Bangalore
# Index: 833, Company: Univariety, HeadQuarter: Hyderabad
# Index: 834, Company: Peel Works, HeadQuarter: Mumbai
# Index: 835, Company: CoreStack, HeadQuarter: Chennai
# Index: 836, Company: Vivriti Capital, HeadQuarter: Chennai
# Index: 837, Company: Agnikul, HeadQuarter: Chennai
# Index: 838, Company: Fintso, HeadQuarter: nan
# Index: 839, Company: Khatabook, HeadQuarter: Bangalore
# Index: 840, Company: Smart Coin, HeadQuarter: nan
# Index: 841, Company: ZunRoof, HeadQuarter: Gurugram
# Index: 842, Company: Shop101, HeadQuarter: nan
# Index: 843, Company: OM Bhakti, HeadQuarter: Bangalore
# Index: 844, Company: Lal10, HeadQuarter: Uttar Pradesh
# Index: 845, Company: Anaxee Digital Runner, HeadQuarter: Indore
# Index: 846, Company: CollegeKhabri, HeadQuarter: Bhopal
# Index: 847, Company: Ola Electric, HeadQuarter: Bangalore
# Index: 848, Company: Multi Living, HeadQuarter: Mumbai
# Index: 849, Company: FamPay, HeadQuarter: Bangalore
# Index: 850, Company: UnboxRobotics Labs, HeadQuarter: Bangalore
# Index: 851, Company: Karbon Card, HeadQuarter: Bangalore
# Index: 852, Company: Airmeet, HeadQuarter: Bangalore
# Index: 853, Company: Innerchef, HeadQuarter: Gurgaon
# Index: 854, Company: Epigamia, HeadQuarter: Mumbai
# Index: 855, Company: StyleNook, HeadQuarter: Mumbai
# Index: 856, Company: Callido Learning, HeadQuarter: Mumbai
# Index: 857, Company: Soxytoes, HeadQuarter: Delhi
# Index: 858, Company: F5, HeadQuarter: Delhi
# Index: 859, Company: Paper Boat, HeadQuarter: Bangalore
# Index: 860, Company: Strata, HeadQuarter: Bangalore
# Index: 861, Company: Salesken, HeadQuarter: Bangalore
# Index: 862, Company: Arya, HeadQuarter: Noida
# Index: 863, Company: Leap Finance, HeadQuarter: Bangalore
# Index: 864, Company: Sleepy Owl, HeadQuarter: Delhi
# Index: 865, Company: Tricog, HeadQuarter: Bangalore
# Index: 866, Company: GogoBus, HeadQuarter: Delhi
# Index: 867, Company: Trell, HeadQuarter: Bangalore
# Index: 868, Company: Spaciya Consultants, HeadQuarter: Noida
# Index: 869, Company: Bounce, HeadQuarter: Bangalore
# Index: 870, Company: Neeman, HeadQuarter: nan
# Index: 871, Company: Chqbook, HeadQuarter: Gurugram
# Index: 872, Company: SMEcorner, HeadQuarter: Mumbai
# Index: 873, Company: Oda Class, HeadQuarter: Bangalore
# Index: 874, Company: Spinny, HeadQuarter: Haryana
# Index: 875, Company: goStops, HeadQuarter: Delhi
# Index: 876, Company: Umeed Housing, HeadQuarter: Haryana
# Index: 877, Company: Vogo, HeadQuarter: Bangalore
# Index: 878, Company: Flick Stree, HeadQuarter: Mumbai
# Index: 879, Company: Qure ai, HeadQuarter: Mumbai
# Index: 880, Company: MinionLabs, HeadQuarter: Bangalore
# Index: 881, Company: Josh Talks, HeadQuarter: Haryana
# Index: 882, Company: PhoneParLoan, HeadQuarter: Delhi
# Index: 883, Company: RailYatri, HeadQuarter: Noida
# Index: 884, Company: AjnaLens, HeadQuarter: Thane
# ...
# Index: 4238, Company: Disprz, HeadQuarter: Mumbai
# Index: 4239, Company: Arbo Works, HeadQuarter: Mountain View, CA
# Index: 4240, Company: Inzpira, HeadQuarter: Trivandrum
# Index: 4241, Company: Defy, HeadQuarter: Bangalore
# Index: 4242, Company: Mindhouse, HeadQuarter: Gurugram
# Index: 4243, Company: Homversity, HeadQuarter: Ahmedabad
# Index: 4244, Company: Toppersnotes, HeadQuarter: Jaipur
# Index: 4245, Company: NoBroker.com, HeadQuarter: Bangalore
# Index: 4246, Company: Haber, HeadQuarter: Pune
# Index: 4247, Company: True Balance, HeadQuarter: Gurugram
# Index: 4248, Company: Recordent, HeadQuarter: Hyderabad
# Index: 4249, Company: Koparo, HeadQuarter: New Delhi
# Index: 4250, Company: Indifi, HeadQuarter: Gurugram
# Index: 4251, Company: Settl, HeadQuarter: Bangalore
# Index: 4252, Company: Park+, HeadQuarter: New Delhi
# Index: 4253, Company: Simple Energy, HeadQuarter: Bangalore
# Index: 4254, Company: Dream Sports, HeadQuarter: Mumbai
# Index: 4255, Company: Spinny, HeadQuarter: Gurugram
# Index: 4256, Company: Rentomojo, HeadQuarter: Bangalore
# Index: 4257, Company: Slice, HeadQuarter: Bangalore
# Index: 4258, Company: 21K School, HeadQuarter: Bangalore
# Index: 4259, Company: Adda247, HeadQuarter: Gurugram
# Index: 4260, Company: Loop Health, HeadQuarter: Pune
# Index: 4261, Company: Rupifi, HeadQuarter: Bangalore
# Index: 4262, Company: RENEE Cosmetics, HeadQuarter: Ahmedabad
# Index: 4263, Company: Svish, HeadQuarter: Gurugram
# Index: 4264, Company: Progcap, HeadQuarter: New Delhi
# Index: 4265, Company: Smartstaff, HeadQuarter: Bangalore
# Index: 4266, Company: D’Moksha Homes, HeadQuarter: Mumbai
# Index: 4267, Company: ANS Commerce, HeadQuarter: Gurugram
# Index: 4268, Company: Mobileware Technologies, HeadQuarter: Mumbai
# Index: 4269, Company: GramCover, HeadQuarter: Noida
# Index: 4270, Company: BYJU'S, HeadQuarter: Bangalore
# Index: 4271, Company: Hyperface, HeadQuarter: Bangalore
# Index: 4272, Company: Licious, HeadQuarter: Bangalore
# Index: 4273, Company: Chalo, HeadQuarter: Mumbai
# Index: 4274, Company: Kaar Technologies, HeadQuarter: Chennai
# Index: 4275, Company: Kissan Pro, HeadQuarter: Jharkhand
# Index: 4276, Company: Sunstone Eduversity, HeadQuarter: Gurugram
# Index: 4277, Company: Ozonetel, HeadQuarter: Hyderabad
# Index: 4278, Company: CoinSwitch Kuber, HeadQuarter: Bangalore
# Index: 4279, Company: Pazcare, HeadQuarter: Bangalore
# Index: 4280, Company: kWh Bikes, HeadQuarter: Bangalore
# Index: 4281, Company: IBSFINtech, HeadQuarter: Bangalore
# Index: 4282, Company: LeadSquared, HeadQuarter: Bangalore
# Index: 4283, Company: Phool.co, HeadQuarter: Kanpur
# Index: 4284, Company: Twin Health, HeadQuarter: Chennai
# Index: 4285, Company: Trica, HeadQuarter: Mumbai
# Index: 4286, Company: mHealth, HeadQuarter: New Delhi
# Index: 4287, Company: Rebel Foods, HeadQuarter: Mumbai
# Index: 4288, Company: ProfitWheel, HeadQuarter: Mumbai
# Index: 4289, Company: Log 9 Materials, HeadQuarter: Bangalore
# Index: 4290, Company: Chingari, HeadQuarter: Bangalore
# Index: 4291, Company: Ishitva, HeadQuarter: Ahmedabad
# Index: 4292, Company: Ola Electric, HeadQuarter: Bangalore
# Index: 4293, Company: leap.club, HeadQuarter: Gurugram
# Index: 4294, Company: F5, HeadQuarter: New Delhi
# Index: 4295, Company: ForeignAdmits, HeadQuarter: Bangalore
# Index: 4296, Company: SALT, HeadQuarter: Bangalore
# Index: 4297, Company: EarnWealth, HeadQuarter: Pune
# Index: 4298, Company: Visit Health, HeadQuarter: New Delhi
# Index: 4299, Company: Crater.Club, HeadQuarter: Bangalore
# Index: 4300, Company: NFTically, HeadQuarter: Gurugram
# Index: 4301, Company: ReshaMandi, HeadQuarter: Bangalore
# Index: 4302, Company: Zetwerk, HeadQuarter: Bangalore
# Index: 4303, Company: Hubilo, HeadQuarter: Ahmedabad
# Index: 4304, Company: M2P Fintech, HeadQuarter: Chennai
# Index: 4305, Company: Open Financial Technologies, HeadQuarter: Bangalore
# Index: 4306, Company: Niro, HeadQuarter: Bangalore
# Index: 4307, Company: Wiingy, HeadQuarter: Bangalore
# Index: 4308, Company: CarDekho, HeadQuarter: Jaipur
# Index: 4309, Company: Melorra, HeadQuarter: Bangalore
# Index: 4310, Company: AnKa SumMor, HeadQuarter: Bangalore
# Index: 4311, Company: Toch.ai, HeadQuarter: Mumbai
# Index: 4312, Company: Playto Labs, HeadQuarter: Bangalore
# Index: 4313, Company: Fraazo, HeadQuarter: Mumbai
# Index: 4314, Company: Arcana, HeadQuarter: Bangalore
# Index: 4315, Company: FloCareer, HeadQuarter: Bangalore
# Index: 4316, Company: Nap Chief, HeadQuarter: Mumbai
# Index: 4317, Company: AcknoLedger, HeadQuarter: Mumbai
# Index: 4318, Company: ApplicateAI, HeadQuarter: Gurugram
# Index: 4319, Company: VLCC Health Care, HeadQuarter: Gurugram
# Index: 4320, Company: Duroflex, HeadQuarter: Bangalore
# Index: 4321, Company: Aviom India, HeadQuarter: Bhilwara
# Index: 4322, Company: Onato, HeadQuarter: Bangalore
# Index: 4323, Company: Mestastop Solutions, HeadQuarter: Bangalore
# Index: 4324, Company: SaaS Labs, HeadQuarter: Noida
# Index: 4325, Company: Devnagri, HeadQuarter: Noida
# Index: 4326, Company: CRED, HeadQuarter: Bangalore
# Index: 4327, Company: ConveGenius, HeadQuarter: Noida
# Index: 4328, Company: Totality, HeadQuarter: Gurugram
# Index: 4329, Company: CredAble, HeadQuarter: Mumbai
# Index: 4330, Company: MarketWolf, HeadQuarter: Mumbai
# Index: 4331, Company: Wondrlab, HeadQuarter: Mumbai
# Index: 4332, Company: SUN Mobility, HeadQuarter: Bangalore
# Index: 4333, Company: Tamasha, HeadQuarter: Mumbai
# Index: 4334, Company: Revfin, HeadQuarter: New Delhi
# Index: 4335, Company: Yu Foodlabs, HeadQuarter: Gurugram
# Index: 4336, Company: MergerDomo, HeadQuarter: New Delhi
# Index: 4337, Company: FarMart, HeadQuarter: Gurugram
# Index: 4338, Company: Questt, HeadQuarter: Gurugram
# Index: 4339, Company: IDfy, HeadQuarter: Mumbai
# Index: 4340, Company: ClearDekho, HeadQuarter: Ghaziabad
# Index: 4341, Company: BookingJini, HeadQuarter: Gurugram
# Index: 4342, Company: Sourcewiz, HeadQuarter: Gurugram
# Index: 4343, Company: Tvasta, HeadQuarter: Chennai
# Index: 4344, Company: Kafqa Academy, HeadQuarter: Bangalore
# Index: 4345, Company: Trell, HeadQuarter: Bangalore
# Index: 4346, Company: Storia, HeadQuarter: Mumbai
# Index: 4347, Company: Clear, HeadQuarter: Bangalore
# Index: 4348, Company: Groww, HeadQuarter: Bangalore
# Index: 4349, Company: The Indus Valley, HeadQuarter: Chennai
# Index: 4350, Company: BharatPe, HeadQuarter: New Delhi
# Index: 4351, Company: Teachmint, HeadQuarter: Bangalore
# Index: 4352, Company: Porter, HeadQuarter: Bangalore
# Index: 4353, Company: O4S, HeadQuarter: Gurugram
# Index: 4354, Company: Wobb, HeadQuarter: Gurugram
# Index: 4355, Company: BASIC Home Loan, HeadQuarter: Gurugram
# Index: 4356, Company: Siply, HeadQuarter: Bangalore
# Index: 4357, Company: BankSathi, HeadQuarter: New Delhi
# Index: 4358, Company: Gramophone, HeadQuarter: Indore
# Index: 4359, Company: Healofy, HeadQuarter: Bangalore
# Index: 4360, Company: E42, HeadQuarter: Pune
# Index: 4361, Company: Spottabl, HeadQuarter: Bangalore
# Index: 4362, Company: DeHaat, HeadQuarter: Gurugram
# Index: 4363, Company: Shumee, HeadQuarter: Bangalore
# Index: 4364, Company: Zolve, HeadQuarter: Bangalore
# Index: 4365, Company: Instoried, HeadQuarter: Bangalore
# Index: 4366, Company: SportZchain, HeadQuarter: Mumbai
# Index: 4367, Company: Hypto, HeadQuarter: Chennai
# Index: 4368, Company: CHUPPS, HeadQuarter: Mumbai
# Index: 4369, Company: Zenduty, HeadQuarter: Bangalore
# Index: 4370, Company: R for Rabbit, HeadQuarter: Ahmedabad
# Index: 4371, Company: Acko, HeadQuarter: Bangalore
# Index: 4372, Company: LoveLocal, HeadQuarter: Mumbai
# Index: 4373, Company: SupplyNote, HeadQuarter: Noida
# Index: 4374, Company: Vakilsearch, HeadQuarter: Chennai
# Index: 4375, Company: Cloudphysician, HeadQuarter: Bangalore
# Index: 4376, Company: Wiggles.in, HeadQuarter: Pune
# Index: 4377, Company: Avanti Finance, HeadQuarter: Bangalore
# Index: 4378, Company: Vanity Wagon, HeadQuarter: New Delhi
# Index: 4379, Company: Purplle, HeadQuarter: Mumbai
# Index: 4380, Company: Wallmantra, HeadQuarter: Noida
# Index: 4381, Company: MFine, HeadQuarter: Bangalore
# Index: 4382, Company: Aquatein, HeadQuarter: Mumbai
# Index: 4383, Company: Mentza, HeadQuarter: Mumbai
# Index: 4384, Company: ConnectedH, HeadQuarter: Gurugram
# Index: 4385, Company: CredAvenue, HeadQuarter: Chennai
# Index: 4386, Company: Vedantu, HeadQuarter: Bangalore
# Index: 4387, Company: Exotel, HeadQuarter: Bangalore
# Index: 4388, Company: Fantasy Akhada, HeadQuarter: Gurugram
# Index: 4389, Company: Meesho, HeadQuarter: Bangalore
# Index: 4390, Company: PumPumPum, HeadQuarter: Gurugram
# Index: 4391, Company: Cusmat, HeadQuarter: Hyderabad
# Index: 4392, Company: Homeville, HeadQuarter: Mumbai
# Index: 4393, Company: Coinshift, HeadQuarter: Chandigarh
# Index: 4394, Company: Strip Finance, HeadQuarter: Hyderabad
# Index: 4395, Company: Ola Electric, HeadQuarter: Bangalore
# Index: 4396, Company: Kolo, HeadQuarter: Bangalore
# Index: 4397, Company: Chqbook, HeadQuarter: Gurugram
# Index: 4398, Company: My3DSelfie, HeadQuarter: Guwahati
# Index: 4399, Company: EV Plugs, HeadQuarter: Gurugram
# Index: 4400, Company: Rulezero, HeadQuarter: Bangalore
# Index: 4401, Company: CredRight, HeadQuarter: Hyderabad
# Index: 4402, Company: Karbon Card, HeadQuarter: Bangalore
# Index: 4403, Company: Auntie Fung, HeadQuarter: Bangalore
# Index: 4404, Company: ePayLater, HeadQuarter: Mumbai
# Index: 4405, Company: Fittr, HeadQuarter: Pune
# Index: 4406, Company: Medikabazaar, HeadQuarter: Mumbai
# Index: 4407, Company: Nimble Growth Organics, HeadQuarter: Bangalore
# Index: 4408, Company: Delhivery, HeadQuarter: Gurugram
# Index: 4409, Company: Akudo, HeadQuarter: Bangalore
# Index: 4410, Company: Sanctum Wealth, HeadQuarter: Mumbai
# Index: 4411, Company: 88academics, HeadQuarter: New Delhi
# Index: 4412, Company: Upgame, HeadQuarter: Gurugram
# Index: 4413, Company: Sanfe, HeadQuarter: New Delhi
# Index: 4414, Company: PredictiVu, HeadQuarter: Gurugram
# Index: 4415, Company: Sterling Accuris Wellness, HeadQuarter: Ahmedabad
# Index: 4416, Company: Bijnis, HeadQuarter: New Delhi
# Index: 4417, Company: Capital Float, HeadQuarter: Bangalore
# Index: 4418, Company: Manch Technologies, HeadQuarter: Bangalore
# Index: 4419, Company: Sochcast, HeadQuarter: Online Media	#REF!
# Index: 4420, Company: Glamyo Health, HeadQuarter: New Delhi
# Index: 4421, Company: CashBook, HeadQuarter: Gurugram
# Index: 4422, Company: The Money Club, HeadQuarter: Noida
# Index: 4423, Company: SuperZop, HeadQuarter: Mumbai
# Index: 4424, Company: Zypp Electric, HeadQuarter: Gurugram
# Index: 4425, Company: Alpha Coach, HeadQuarter: Mumbai
# Index: 4426, Company: VRO Hospitality, HeadQuarter: Bangalore
# Index: 4427, Company: byteXL, HeadQuarter: Hyderabad
# Index: 4428, Company: Leena AI, HeadQuarter: Gurugram
# Index: 4429, Company: CARS24, HeadQuarter: Gurugram
# Index: 4430, Company: Klub, HeadQuarter: Bangalore
# Index: 4431, Company: Bluepad, HeadQuarter: Bangalore
# Index: 4432, Company: FloBiz, HeadQuarter: Bangalore
# Index: 4433, Company: Tummoc, HeadQuarter: Bangalore
# Index: 4434, Company: Design Cafe, HeadQuarter: Bangalore
# Index: 4435, Company: PayCardo, HeadQuarter: Pune
# Index: 4436, Company: Aerchain, HeadQuarter: Bangalore
# Index: 4437, Company: Expertrons, HeadQuarter: Mumbai
# Index: 4438, Company: CuriousJr, HeadQuarter: Gurugram
# Index: 4439, Company: Wow! Momo, HeadQuarter: Kolkata
# Index: 4440, Company: Supertails, HeadQuarter: Bangalore
# Index: 4441, Company: LifeCell, HeadQuarter: Chennai
# Index: 4442, Company: ZestMoney, HeadQuarter: Bangalore
# Index: 4443, Company: FrontRow, HeadQuarter: Bangalore
# Index: 4444, Company: HappyCredit, HeadQuarter: Bangalore
# Index: 4445, Company: Endimension, HeadQuarter: Mumbai
# Index: 4446, Company: Frenzi, HeadQuarter: Mumbai
# Index: 4447, Company: Leverage Edu, HeadQuarter: New Delhi
# Index: 4448, Company: BeepKart, HeadQuarter: Bangalore
# Index: 4449, Company: Lio, HeadQuarter: Pune
# Index: 4450, Company: TravClan, HeadQuarter: New Delhi
# Index: 4451, Company: WickedGud, HeadQuarter: Mumbai
# Index: 4452, Company: Enercomp, HeadQuarter: Ahmedabad
# Index: 4453, Company: BetterPlace, HeadQuarter: Bangalore
# Index: 4454, Company: Medpho, HeadQuarter: Noida
# Index: 4455, Company: LivQuik Technology, HeadQuarter: Mumbai
# Index: 4456, Company: EventBeep, HeadQuarter: Pune
# Index: 4457, Company: GTM Buddy, HeadQuarter: Hyderabad
# Index: 4458, Company: Gobbly, HeadQuarter: Gurugram
# Index: 4459, Company: HexaHealth, HeadQuarter: Mumbai
# Index: 4460, Company: Eupheus Learning, HeadQuarter: New Delhi
# Index: 4461, Company: Easiloan, HeadQuarter: Mumbai
# Index: 4462, Company: Anar, HeadQuarter: Mumbai
# Index: 4463, Company: Shadez, HeadQuarter: Mumbai
# Index: 4464, Company: Vahan, HeadQuarter: Bangalore
# Index: 4465, Company: MPL, HeadQuarter: Bangalore
# Index: 4466, Company: Tinkerly, HeadQuarter: Jaipur
# Index: 4467, Company: Godamwale, HeadQuarter: Mumbai
# Index: 4468, Company: Artium Academy, HeadQuarter: Mumbai
# Index: 4469, Company: Awon GameZ, HeadQuarter: Noida
# Index: 4470, Company: Ayu Health, HeadQuarter: Bangalore
# Index: 4471, Company: Apna, HeadQuarter: Bangalore
# Index: 4472, Company: BharatAgri, HeadQuarter: Bangalore
# Index: 4473, Company: Flatheads, HeadQuarter: Bangalore
# Index: 4474, Company: Boutique Spirit Brands, HeadQuarter: New Delhi
# Index: 4475, Company: eShipz, HeadQuarter: Bangalore
# Index: 4476, Company: Pine Labs, HeadQuarter: Noida
# Index: 4477, Company: Paytail, HeadQuarter: New Delhi
# Index: 4478, Company: 4Fin, HeadQuarter: Pune
# Index: 4479, Company: Atomberg Technologies, HeadQuarter: Mumbai
# Index: 4480, Company: Genext Students, HeadQuarter: Mumbai
# Index: 4481, Company: immunitoAI, HeadQuarter: Bangalore
# Index: 4482, Company: GameEon Studios, HeadQuarter: Mumbai
# Index: 4483, Company: Farmers Fresh Zone, HeadQuarter: Kochi
# Index: 4484, Company: Anveshan, HeadQuarter: Bangalore
# Index: 4485, Company: OckyPocky, HeadQuarter: Gurugram
# Index: 4486, Company: Coutloot, HeadQuarter: Mumbai
# Index: 4487, Company: Nova Benefits, HeadQuarter: Bangalore
# Index: 4488, Company: HomeLane, HeadQuarter: Bangalore
# Index: 4489, Company: Lido Learning, HeadQuarter: Mumbai
# Index: 4490, Company: Jar, HeadQuarter: Bangalore
# Index: 4491, Company: Peppermint, HeadQuarter: Pune
# Index: 4492, Company: moneyHOP, HeadQuarter: London
# Index: 4493, Company: Codingal, HeadQuarter: Bangalore
# Index: 4494, Company: Skit, HeadQuarter: Bangalore
# Index: 4495, Company: Peak, HeadQuarter: Information Technology & Services
# Index: 4496, Company: REVOS, HeadQuarter: Bangalore
# Index: 4497, Company: Dezerv., HeadQuarter: Mumbai
# Index: 4498, Company: AppsForBharat, HeadQuarter: Bangalore
# Index: 4499, Company: Habbit, HeadQuarter: Bangalore
# Index: 4500, Company: Bikayi, HeadQuarter: Hyderabad
# Index: 4501, Company: Sugar.fit, HeadQuarter: Bangalore
# Index: 4502, Company: Dukaan, HeadQuarter: Bangalore
# Index: 4503, Company: Vidyakul, HeadQuarter: Gurugram
# Index: 4504, Company: Goodmylk, HeadQuarter: Bangalore
# Index: 4505, Company: Fieldproxy, HeadQuarter: Chennai
# Index: 4506, Company: NeuroPixel.AI, HeadQuarter: Bangalore
# Index: 4507, Company: Elixia Tech Solutions, HeadQuarter: Mumbai
# Index: 4508, Company: bitsCrunch, HeadQuarter: Chennai
# Index: 4509, Company: Prolgae, HeadQuarter: The Nilgiris
# Index: 4510, Company: Biddano, HeadQuarter: Pune
# Index: 4511, Company: Geniemode, HeadQuarter: Gurugram
# Index: 4512, Company: Sapio Analytics, HeadQuarter: Mumbai
# Index: 4513, Company: Neokred, HeadQuarter: Bangalore
# Index: 4514, Company: Delhivery, HeadQuarter: Gurugram
# Index: 4515, Company: Flipspaces, HeadQuarter: Mumbai
# Index: 4516, Company: Fleek, HeadQuarter: Bangalore
# Index: 4517, Company: GoKwik, HeadQuarter: New Delhi
# Index: 4518, Company: Proeon, HeadQuarter: Pune
# Index: 4519, Company: InfyU Labs, HeadQuarter: Gandhinagar
# Index: 4520, Company: TechEagle, HeadQuarter: Gurugram
# Index: 4521, Company: Voxelgrids, HeadQuarter: Bangalore
# Index: 4522, Company: Cogos Technologies, HeadQuarter: Bangalore
# Index: 4523, Company: Gigforce, HeadQuarter: Gurugram
# Index: 4524, Company: Vahdam, HeadQuarter: New Delhi
# Index: 4525, Company: Leap Finance, HeadQuarter: Bangalore
# Index: 4526, Company: CollegeDekho, HeadQuarter: Gurugram
# Index: 4527, Company: WeRize, HeadQuarter: Bangalore

# %%
combined_df.at[29,'HeadQuarter'] = 'New Delhi'
combined_df.at[32,'HeadQuarter'] = 'Andhra Pradesh'
combined_df.at[43,'HeadQuarter'] = 'Faridabad'
combined_df.at[98,'HeadQuarter'] = 'Bengaluru'
combined_df.at[111,'HeadQuarter'] = 'Bengaluru'
combined_df.at[241,'HeadQuarter'] = 'New Delhi'
combined_df.at[242,'HeadQuarter'] = 'Mumbai'
combined_df.at[255,'HeadQuarter'] = 'New Delhi'
combined_df.at[256,'HeadQuarter'] = 'Mumbai'
combined_df.at[257,'HeadQuarter'] = 'Gurugram'
combined_df.at[806,'HeadQuarter'] = 'Faridabad'
combined_df.at[1100,'HeadQuarter'] = 'Bangalore'
combined_df.at[1176,'HeadQuarter'] = 'Manchester'
combined_df.at[1287,'HeadQuarter'] = 'Tirunelveli'
combined_df.at[1370,'HeadQuarter'] = 'Jaipur'
combined_df.at[1375,'HeadQuarter'] = 'Frisco'
combined_df.at[1393,'HeadQuarter'] = 'Dhingsara'
combined_df.at[1395,'HeadQuarter'] = 'New York'
combined_df.at[1400,'HeadQuarter'] = 'Jaipur'
combined_df.at[1407,'HeadQuarter'] = 'Jaipur'
combined_df.at[1432,'HeadQuarter'] = 'San Francisco'
combined_df.at[1434,'HeadQuarter'] = 'San Francisco'
combined_df.at[1438,'HeadQuarter'] = 'San Ramon'
combined_df.at[1439,'HeadQuarter'] = 'Paris'
combined_df.at[1441,'HeadQuarter'] = 'Texas'
combined_df.at[1449,'HeadQuarter'] = 'San Francisco'
combined_df.at[1469,'HeadQuarter'] = 'London'
combined_df.at[1470,'HeadQuarter'] = 'Sydney'
combined_df.at[1471,'HeadQuarter'] = 'Milano'
combined_df.at[1473,'HeadQuarter'] = 'New York'
combined_df.at[1474,'HeadQuarter'] = 'Queensland'
combined_df.at[1482,'HeadQuarter'] = 'London'
combined_df.at[1488,'HeadQuarter'] = 'San Francisco'
combined_df.at[1491,'HeadQuarter'] = 'Trivandrum'
combined_df.at[1493,'HeadQuarter'] = 'Samastipur'
combined_df.at[1496,'HeadQuarter'] = 'Irvine'
combined_df.at[1497,'HeadQuarter'] = 'Tumkur'
combined_df.at[1501,'HeadQuarter'] = 'San Francisco'
combined_df.at[1509,'HeadQuarter'] = 'San Francisco'
combined_df.at[1510,'HeadQuarter'] = 'Newcastle'
combined_df.at[1512,'HeadQuarter'] = 'Shanghai'
combined_df.at[1515,'HeadQuarter'] = 'Jiaxing'
combined_df.at[1578,'HeadQuarter'] = 'San Francisco'
combined_df.at[1593,'HeadQuarter'] = 'Tangerang'
combined_df.at[1696,'HeadQuarter'] = 'Hyderabad'
combined_df.at[1708,'HeadQuarter'] = 'Bengaluru'
combined_df.at[1709,'HeadQuarter'] = 'Gurugram'
combined_df.at[1724,'HeadQuarter'] = 'Noida'
combined_df.at[1725,'HeadQuarter'] = 'Andhra Pradesh'
combined_df.at[1728,'HeadQuarter'] = 'New Delhi'
combined_df.at[1772,'HeadQuarter'] = 'New Delhi'
combined_df.at[1831,'HeadQuarter'] = 'Mumbai'
combined_df.at[1835,'HeadQuarter'] = 'Bengaluru'
combined_df.at[1844,'HeadQuarter'] = 'Pune'
combined_df.at[1856,'HeadQuarter'] = 'Bengaluru'
combined_df.at[1857,'HeadQuarter'] = 'Bangalore'
combined_df.at[1858,'HeadQuarter'] = 'Seattle'
combined_df.at[1860,'HeadQuarter'] = 'Bangalore'
combined_df.at[1866,'HeadQuarter'] = 'Bangalore'
combined_df.at[1874,'HeadQuarter'] = 'New Delhi'
combined_df.at[1877,'HeadQuarter'] = 'Bengaluru'
combined_df.at[1903,'HeadQuarter'] = 'Gurgaon'
combined_df.at[1908,'HeadQuarter'] = 'Coimbatore'
combined_df.at[1919,'HeadQuarter'] = 'New Delhi'
combined_df.at[1923,'HeadQuarter'] = 'Bangalore'
combined_df.at[1924,'HeadQuarter'] = 'Thane'
combined_df.at[1925,'HeadQuarter'] = 'Singapore'
combined_df.at[1937,'HeadQuarter'] = 'Bengaluru'
combined_df.at[1946,'HeadQuarter'] = 'Ahmedabad'
combined_df.at[1952,'HeadQuarter'] = 'Chennai'
combined_df.at[1956,'HeadQuarter'] = 'Bengaluru'
combined_df.at[1966,'HeadQuarter'] = 'Bengaluru'
combined_df.at[1977,'HeadQuarter'] = 'Bengaluru'
combined_df.at[1982,'HeadQuarter'] = 'London'
combined_df.at[1984,'HeadQuarter'] = 'New York'
combined_df.at[1985,'HeadQuarter'] = 'Panaji'
combined_df.at[1987,'HeadQuarter'] = 'Mumbai'
combined_df.at[1989,'HeadQuarter'] = 'Bengaluru'
combined_df.at[1994,'HeadQuarter'] = 'Mumbai'
combined_df.at[2000,'HeadQuarter'] = 'Mumbai'
combined_df.at[2002,'HeadQuarter'] = 'Mumbai'
combined_df.at[2004,'HeadQuarter'] = 'Gurugram'
combined_df.at[2005,'HeadQuarter'] = 'Gurugram'
combined_df.at[2009,'HeadQuarter'] = 'Bangalore'
combined_df.at[2011,'HeadQuarter'] = 'Jakarta'
combined_df.at[2013,'HeadQuarter'] = 'San Fransisco'
combined_df.at[2035,'HeadQuarter'] = 'Mumbai'
combined_df.at[2036,'HeadQuarter'] = 'New Delhi'
combined_df.at[2047,'HeadQuarter'] = 'Mumbai'
combined_df.at[2049,'HeadQuarter'] = 'Bengaluru'
combined_df.at[2051,'HeadQuarter'] = 'Mumbai'
combined_df.at[2079,'HeadQuarter'] = 'Hyderabad'
combined_df.at[2098,'HeadQuarter'] = 'San Fransisco'
combined_df.at[2099,'HeadQuarter'] = 'Bangalore'
combined_df.at[2112,'HeadQuarter'] = 'Noida'
combined_df.at[2114,'HeadQuarter'] = 'London'
combined_df.at[2115,'HeadQuarter'] = 'Mumbai'
combined_df.at[2136,'HeadQuarter'] = 'New Delhi'
combined_df.at[2138,'HeadQuarter'] = 'Noida'
combined_df.at[2139,'HeadQuarter'] = 'Delhi'
combined_df.at[2141,'HeadQuarter'] = 'Stockholm'
combined_df.at[2144,'HeadQuarter'] = 'Bangalore'
combined_df.at[2146,'HeadQuarter'] = 'Mumbai'
combined_df.at[2155,'HeadQuarter'] = 'Mumbai'
combined_df.at[2159,'HeadQuarter'] = 'Gurugram'
combined_df.at[2162,'HeadQuarter'] = 'New Delhi'
combined_df.at[2169,'HeadQuarter'] = 'Hyderabad'
combined_df.at[2179,'HeadQuarter'] = 'Bangalore'
combined_df.at[2191,'HeadQuarter'] = 'New York'
combined_df.at[2196,'HeadQuarter'] = 'Gurugram'
combined_df.at[2198,'HeadQuarter'] = 'Bangalore'
combined_df.at[2199,'HeadQuarter'] = 'California'
combined_df.at[2203,'HeadQuarter'] = 'Illinois'
combined_df.at[2204,'HeadQuarter'] = 'Singapore'
combined_df.at[2205,'HeadQuarter'] = 'Bengaluru'
combined_df.at[2211,'HeadQuarter'] = 'Massachusetts'
combined_df.at[2213,'HeadQuarter'] = 'Hyderabad'
combined_df.at[2217,'HeadQuarter'] = 'Ahmedabad'
combined_df.at[2225,'HeadQuarter'] = 'New Delhi'
combined_df.at[2228,'HeadQuarter'] = 'Bengaluru'
combined_df.at[2234,'HeadQuarter'] = 'San Fransisco'
combined_df.at[2236,'HeadQuarter'] = 'New Delhi'
combined_df.at[2238,'HeadQuarter'] = 'Mumbai'
combined_df.at[2240,'HeadQuarter'] = 'Mumbai'
combined_df.at[2241,'HeadQuarter'] = 'Gurgaon'
combined_df.at[2242,'HeadQuarter'] = 'Bengaluru'
combined_df.at[2243,'HeadQuarter'] = 'Gurgaon'
combined_df.at[2244,'HeadQuarter'] = 'Bangalore'
combined_df.at[2250,'HeadQuarter'] = 'Noida'
combined_df.at[2254,'HeadQuarter'] = 'Pune'
combined_df.at[2256,'HeadQuarter'] = 'New Delhi'
combined_df.at[2260,'HeadQuarter'] = 'Bangalore'
combined_df.at[2264,'HeadQuarter'] = 'New Delhi'
combined_df.at[2272,'HeadQuarter'] = 'Massachusetts'
combined_df.at[2278,'HeadQuarter'] = 'Mumbai'
combined_df.at[2280,'HeadQuarter'] = 'Bangalore'
combined_df.at[2282,'HeadQuarter'] = 'Mumbai'
combined_df.at[2285,'HeadQuarter'] = 'Gurgaon'
combined_df.at[2286,'HeadQuarter'] = 'San Francisco'
combined_df.at[2291,'HeadQuarter'] = 'San Francisc'
combined_df.at[2293,'HeadQuarter'] = 'Gurugram'
combined_df.at[2295,'HeadQuarter'] = 'Gurgaon'
combined_df.at[2298,'HeadQuarter'] = 'Gurugram'
combined_df.at[2305,'HeadQuarter'] = 'Gurgaon'
combined_df.at[2307,'HeadQuarter'] = 'Bengaluru'
combined_df.at[2318,'HeadQuarter'] = 'Gurugram'
combined_df.at[2329,'HeadQuarter'] = 'New Delhi'
combined_df.at[2334,'HeadQuarter'] = 'Chennai'
combined_df.at[2340,'HeadQuarter'] = 'Bengaluru'
combined_df.at[2343,'HeadQuarter'] = 'Bangalore'
combined_df.at[2365,'HeadQuarter'] = 'Atlanta'
combined_df.at[2395,'HeadQuarter'] = 'Faridabad'
combined_df.at[2412,'HeadQuarter'] = 'New Delhi'
combined_df.at[2552,'HeadQuarter'] = 'Noida'

# %% [markdown]
# Stage Column

# %%
combined_df['Stage'].unique()
# Out:
# array([nan, 'Pre-seed', 'Seed', 'Pre-series A', 'Pre-series', 'Series C',
#        'Series A', 'Series B', 'Debt', 'Pre-series C', 'Pre-series B',
#        'Series E', 'Bridge', 'Series D', 'Series B2', 'Series F',
#        'Pre- series A', 'Edge', 'Series H', 'Pre-Series B', 'Seed A',
#        'Series A-1', 'Seed Funding', 'Pre-Seed', 'Seed round',
#        'Pre-seed Round', 'Seed Round & Series A', 'Pre Series A',
#        'Pre seed Round', 'Angel Round', 'Pre series A1', 'Series E2',
#        'Pre series A', 'Seed Round', 'Bridge Round', 'Pre seed round',
#        'Pre series B', 'Pre series C', 'Seed Investment', 'Series D1',
#        'Mid series', 'Series C, D', 'Seed funding', '$1200000', 'Seed+',
#        'Series F2', 'Series A+', 'Series G', 'Series B3', 'PE',
#        'Series F1', 'Pre-series A1', '$300000', 'Early seed', '$6000000',
#        '$1000000', 'Seies A', 'Series A2', 'Series I'], dtype=object)

# %%
# List of values to remove
remove_values = [
    '$1200000', '$300000', '$6000000', '$1000000', 'Undisclosed', 'Edge', 'Mid series', 'Fresh funding', 'Debt', 'PE', 'Bridge Round',
    'Mid series', 'Private Equity','Venture - Series Unknown', 'Grant', 'Debt Financing', 'Post-IPO Debt', 'Corporate Round', 
    'Undisclosed', 'Secondary Market', 'Post-IPO Equity', 'Non-equity Assistance', 'Funding Round', 'Bridge', 'Angel', 'Angel Round'
]

# Filter out rows with unwanted values
df_cleaned = combined_df[~combined_df['Stage'].isin(remove_values)]


# Define the mapping dictionary
stage_mapping = {






    'Pre-Series A': ['Pre Series A', 'Pre series A1', 'Series A2', 'Pre-series A', 'Pre series A', 'Pre-series A', 'Pre series A',
                     'Pre-series A', 'Pre-series A1','Pre series A'],
    'Pre-Series B': ['Pre-Series B', 'Pre Series B'],
    'Series B': ['Series B', 'Series B3', 'Series B+', 'Series B2', 'Venture - Series Unknown', 'Debt'],
    'Series A': ['Series A+', 'Series A-1', 'Series A', 'Seed Round & Series A', 'Pre-series A1'],
    'Series F': ['Series F', 'Series F2', 'Series F1'],
    'Seed': ['Seed Investment', 'Seed Funding', 'Seed funding', 'Seed+', 'Pre-seed Round', 'Seed A', 'Seed fund'],
    'Series E': ['Series E', 'Series E2'],
    'Pre-Series C': ['Pre-Series C', 'Pre Series C'],
    'Series C' : ['Series C, D'],
    'Series D': ['Series D1']
}

# Invert the mapping dictionary to map individual variations to their standard stage names
inverted_mapping = {v: k for k, values in stage_mapping.items() for v in values}

# Apply the mapping to the 'Stage' column permanently
df_cleaned['Stage'] = df_cleaned['Stage'].replace(inverted_mapping)

# Display the updated DataFrame to verify the changes
print(df_cleaned['Stage'].unique())
# Out:
# [nan 'Pre-seed' 'Seed' 'Pre-Series A' 'Pre-series' 'Series C' 'Series A'
#  'Series B' 'Pre-series C' 'Pre-series B' 'Series E' 'Series D' 'Series F'
#  'Pre- series A' 'Series H' 'Pre-Series B' 'Pre-Seed' 'Seed round'
#  'Pre seed Round' 'Seed Round' 'Pre seed round' 'Pre series B'
#  'Pre series C' 'Series G' 'Early seed' 'Seies A' 'Series I']

# %% [markdown]
# Sector Column

# %%
# Handling Missing Values In The Sector Column

# Fill missing values in the 'Sector'column with the most frequent sector

most_frequent_sector = combined_df['Sector'].mode()[0]
combined_df['Sector'].fillna(most_frequent_sector, inplace=True)

# %% [markdown]
# Founders Column

# %%
# Fill missing values in the 'Founders'column with 'Undisclosed'

combined_df['Founders'].fillna('Undisclosed', inplace=True)

# %% [markdown]
# Investor Column

# %%
# Fill missing values in the 'Investor'column with 'Undisclosed'

combined_df['Investor'].fillna('Undisclosed', inplace=True)

# %% [markdown]
# Founded Column

# %%
# Fill missing values in the 'Founded'column with 'Unknown'

combined_df['Founded'].fillna('Unknown', inplace=True)

# %% [markdown]
# Amount Column

# %%
# Fill missing values in the 'Amount' column with the median

amount_median = combined_df['Amount($)'].median()
combined_df['Amount($)'] = combined_df['Amount($)'].fillna(amount_median)
combined_df['Amount($)'].head()
# Out:
# 0    200000.00
# 1    100000.00
# 2   3300000.00
# 3    400000.00
# 4    340000.00
# Name: Amount($), dtype: float64

# %%
# Checking for null values

combined_df.isna().sum()
# Out:
# Company            0
# Founded            0
# HeadQuarter      190
# Sector             0
# What it does       0
# Founders           0
# Investor           0
# Amount($)          0
# Stage           1784
# year               0
# dtype: int64

# %% [markdown]
# For sectors

# %%
# Ensuring consistent formatting for columns


# Categorizing the sectors using regular expression

import re

def sector_redistribution(sector):
    sector = sector.lower()  # Convert sector to lowercase for case-insensitive matching
    
    # Define regular expressions for each broad sector category
    if re.search(r'bank|fintech|finance|crypto|account|credit|venture|crowd|blockchain|lending|trading|wealth|investment|insurance|payments', sector):
        return 'Financial Services'
    elif re.search(r'health|pharma|biotech|med|hospital|clinic|wellness|care|medical|nutrition|diagnostics|life science|device', sector):
        return 'Healthcare'
    elif re.search(r'edu|school|college|learn|tutor|academy|elearning|edtech|training|higher education|skill assessment|stem', sector):
        return 'Education'
    elif re.search(r'tech|software|it|computer|cloud|data|ai|ml|cyber|saas|iot|ar|vr|paas|machine learning|virtual', sector):
        return 'Technology'
    elif re.search(r'media|entertain|film|music|tv|video|publishing|news|streaming|gaming|sports|video games|digital', sector):
        return 'Media and Entertainment'
    elif re.search(r'travel|tour|hotel|restaurant|food|hospitality|tourism|accommodation|leisure|transport|logistics|delivery|automotive|railroad|freight', sector):
        return 'Hospitality and Tourism'
    elif re.search(r'retail|e-commerce|shop|store|mall|ecommerce|shopping|fashion|marketplace|jewelry|interior design|home decor|furniture|beauty', sector):
        return 'Retail and E-Commerce'
    elif re.search(r'energy|power|oil|gas|renewable|solar|wind|cleantech|environmental|natural resources|clean energy', sector):
        return 'Energy'
    elif re.search(r'real estate|property|housing|construction|building|interior design|home renovation|smart home|rental|property management', sector):
        return 'Real Estate'
    elif re.search(r'auto|car|vehicle|transport|logistics|delivery|shipping|automotive tech|electric vehicle|autonomous vehicles', sector):
        return 'Automotive and Transportation'
    elif re.search(r'agri|farm|agriculture|crop|livestock|agtech|farming|food processing|farmers market', sector):
        return 'Agriculture'
    elif re.search(r'consumer goods|fmcg|goods|product|consumer|lifestyle|home services|personalization|wellness', sector):
        return 'Consumer Goods'
    elif re.search(r'aero|defense|military|space|aerospace', sector):
        return 'Aerospace and Defense'
    elif re.search(r'insurance|insure|policy|insurtech|health insurance|life insurance|property insurance', sector):
        return 'Insurance'
    elif re.search(r'utility|water|electric|gas|utilities', sector):
        return 'Utilities'
    elif re.search(r'nonprofit|charity|ngo|social|non-profit|social entrepreneurship|incubators|crowdfunding|funding platform', sector):
        return 'Nonprofit and Social Services'
    elif re.search(r'prof|consult|service|advisor|law|legal|account|business development|consulting|professional services', sector):
        return 'Professional Services'
    elif re.search(r'manufacture|factory|production|industrial|machinery|industrial automation|product design', sector):
        return 'Manufacturing'
    else:
        return 'Other'

# Apply the sector_redistribution function to the Sector column
combined_df['Sector'] = combined_df['Sector'].apply(sector_redistribution)

# %% [markdown]
# For HeadQuarters

# %%
import re

def simplify_location(location):
    # Check if the input is a string
    if isinstance(location, str):
        # Extract only the city name using regular expression
        city = re.split(',|\\s', location)[0]
        return city.strip()
    else:
        # Return the input if it's not a string
        return location

# Apply the function to the HeadQuarter column
combined_df['HeadQuarter'] = combined_df['HeadQuarter'].apply(simplify_location)

# %% [markdown]
# For Amount

# %%
# Assuming all amounts have been converted to USD in previous steps

# Convert to numeric, setting errors='coerce' will convert non-numeric values to NaN
combined_df['Amount($)'] = pd.to_numeric(combined_df['Amount($)'], errors='coerce')

# Set the display option for floating point numbers 
pd.options.display.float_format = '{:.2f}'.format

# Alternatively, round the numbers to two decimal places for display purposes
combined_df['Amount($)'] = combined_df['Amount($)'].round(2)

combined_df['Amount($)'].head()
# Out:
# 0    200000.00
# 1    100000.00
# 2   3300000.00
# 3    400000.00
# 4    340000.00
# Name: Amount($), dtype: float64

# %% [markdown]
# Removing Duplicates

# %%
# Check for duplicates
print(combined_df.duplicated().sum())

# Drop duplicate rows
combined_df.drop_duplicates(inplace=True)
# Out:
# 0

# %% [markdown]
# Outlier Detection And Handling

# %%
print(combined_df['Amount($)'].dtype)
# Out:
# float64

# %%
# Identify outliers using IQR (Interquartile Range)

Q1 = combined_df['Amount($)'].quantile(0.25)
Q3 = combined_df['Amount($)'].quantile(0.75)
IQR = Q3 - Q1

# Define outlier thresholds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
# The factor of 1.5 is a commonly used value for detecting outliers using the IQR method.

# Filter out outliers
outliers = combined_df[(combined_df['Amount($)'] < lower_bound) | (combined_df['Amount($)'] > upper_bound)]
print(f"Number of outliers: {outliers.shape[0]}")

# Remove outliers
combined_df = combined_df[(combined_df['Amount($)'] >= lower_bound) & (combined_df['Amount($)'] <= upper_bound)]
# Out:
# Number of outliers: 452

# %%
# Save the cleaned DataFrame

combined_df.to_csv('clean_combined_dataset.csv', index=False)

# Load the csv into a dataframe

clean_combined_df = pd.read_csv('clean_combined_dataset.csv')

# %%
clean_combined_df.columns
# Out:
# Index(['Company', 'Founded', 'HeadQuarter', 'Sector', 'What it does',
#        'Founders', 'Investor', 'Amount($)', 'Stage', 'year'],
#       dtype='object')

# %% [markdown]
# # Hypothesis Testing

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\mingw\python\lib\site-packages (0.14.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\mingw\python\lib\site-packages (from statsmodels) (2.1.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\mingw\python\lib\site-packages (from statsmodels) (1.15.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\mingw\python\lib\site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\mingw\python\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\mingw\python\lib\site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\mingw\python\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\mingw\python\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\mingw\python\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\mingw\python\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Fit the model
# The Q("Amount($)") syntax is used to handle column names with special characters like $
model = ols('Q("Amount($)") ~ C(Sector)', data=clean_combined_df).fit()

# Perform ANOVA
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)

# Interpret the results
alpha = 0.05
p_value = anova_table['PR(>F)'][0]
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference in the average funding amounts across different sectors.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in the average funding amounts across different sectors.")
# Out:
#                         sum_sq      df    F  PR(>F)
# C(Sector)   199218557793847.78    9.00 5.54    0.00
# Residual  13295160391778364.00 3330.00  NaN     NaN
# Reject the null hypothesis: There is a significant difference in the average funding amounts across different sectors.

# %% [markdown]
# # Analysis

# %%
# Load the csv into a dataframe
import pandas as pd

clean_combined_df = pd.read_csv('clean_combined_dataset.csv')
clean_combined_df
# Out:
#                  Company Founded HeadQuarter                 Sector  \
# 0             Aqgromalin  2019.0     Chennai             Technology
# 1               Krayonnz  2019.0   Bangalore              Education
# 2           PadCare Labs  2018.0        Pune                  Other
# 3                  NCOME  2020.0         New                  Other
# 4             Gramophone  2016.0      Indore             Technology
# ...                  ...     ...         ...                    ...
# 3335           TechEagle  2015.0    Gurugram  Aerospace and Defense
# 3336          Voxelgrids  2017.0   Bangalore             Technology
# 3337  Cogos Technologies  2016.0   Bangalore             Technology
# 3338            Gigforce  2019.0    Gurugram             Technology
# 3339              WeRize  2019.0   Bangalore  Professional Services
#
#                                            What it does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# 3                          Escrow-as-a-service platform
# 4     Gramophone is an AgTech platform enabling acce...
# ...                                                 ...
# 3335  Safe, secure & reliable On-Demand Drone delive...
# 3336  Voxelgrids is an Magnetic Resonance Imaging te...
# 3337  A smart-tech-enabled platform offering a one-s...
# 3338                  A gig/on-demand staffing company.
# 3339  India’s first socially distributed full stack ...
#
#                                                Founders  \
# 0                       Prasanna Manogaran, Bharani C L
# 1                      Saurabh Dixit, Gurudutt Upadhyay
# 2                                       Ajinkya Dhariya
# 3                                         Ritesh Tiwari
# 4     Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
# ...                                                 ...
# 3335                                 Vikram Singh Meena
# 3336                                  Arjun Arunachalam
# 3337                                     Prasad Sreeram
# 3338                        Chirag Mittal, Anirudh Syal
# 3339                      Vishal Chopra, Himanshu Gupta
#
#                                  Investor  Amount($)         Stage  year
# 0                         Angel investors  200000.00           NaN  2018
# 1                         GSF Accelerator  100000.00      Pre-seed  2018
# 2                          Venture Center 3300000.00      Pre-seed  2018
# 3     Venture Catalysts, PointOne Capital  400000.00           NaN  2018
# 4     Siana Capital Management, Info Edge  340000.00           NaN  2018
# ...                                   ...        ...           ...   ...
# 3335                    India Accelerator  500000.00          Seed  2021
# 3336                                 Zoho 5000000.00           NaN  2021
# 3337                     Transworld Group 2000000.00  Pre-series A  2021
# 3338                      Endiya Partners 3000000.00  Pre-series A  2021
# 3339       3one4 Capital, Kalaari Capital 8000000.00      Series A  2021
#
# [3340 rows x 10 columns]

# %%
# Descriptive statistics

# To get an overview of the funding amounts

clean_combined_df['Amount($)'].describe()
# Out:
# count      3340.00
# mean    2610505.26
# std     2010334.11
# min       10000.00
# 25%     1000000.00
# 50%     2990000.00
# 75%     3300000.00
# max     9500000.00
# Name: Amount($), dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-v0_8-darkgrid')

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# Distribution Analysis

# %%
# To get an overview of the spread and identify any skewness 

# In this case we'll use both the histogram 


# Histogram
plt.figure(figsize=(10, 6))
sns.histplot(clean_combined_df['Amount($)'], bins=30, kde=True)
plt.title('Distribution of Funding Amounts')
plt.xlabel('Funding Amount ($)')
plt.ylabel('Frequency')
plt.show()

# %%
# To get an overview of outliers present

# Using a box plot

plt.figure(figsize=(10, 6))
sns.boxplot(x=clean_combined_df['Amount($)'].dropna())  # Drop NaN values
plt.title('Box Plot of Funding Amounts')
plt.xlabel('Funding Amount ($)')
plt.grid(False)
plt.show()

# %% [markdown]
# Time Series Analysis
#
# How has the total amount of funding received by start-ups in India changed from 2018-2021?

# %% [markdown]
# Categorical Analysis
#
# Which sectors have received the most funding in each year?

# %%
# Aggregate the total funding amount by sector
total_funding_by_sector = clean_combined_df.groupby('Sector')['Amount($)'].sum().reset_index()

# Sort the sectors by the total funding amount in descending order
total_funding_by_sector = total_funding_by_sector.sort_values(by='Amount($)', ascending=False)

# Plot the results
plt.figure(figsize=(14, 8))
plt.bar(total_funding_by_sector['Sector'], total_funding_by_sector['Amount($)'])
plt.xticks(rotation=90)
plt.title('Total Funding Received by Each Sector')
plt.xlabel('Sector')
plt.ylabel('Total Funding Amount ($)')
plt.grid(False)
plt.show()

plt.style.use('seaborn-v0_8-dark')

# %%
# Group by investor and sum the funding amounts
funding_by_investor = clean_combined_df.groupby('Investor')['Amount($)'].sum().reset_index()

# Identify top investors
top_investors = funding_by_investor.sort_values(by='Amount($)', ascending=False).head(10)

# Plot the top investors
plt.figure(figsize=(12, 6))
plt.bar(top_investors['Investor'], top_investors['Amount($)'])
plt.title('Top Investors in the India Start-up Ecosystem (2018-2021)')
plt.xlabel('Investor')
plt.ylabel('Total Funding ($)')
plt.xticks(rotation=45)
plt.grid(False)
plt.show()

# %%
# Remove entries where Stage is not a string (e.g., a function object)
combined_df = combined_df[combined_df['Stage'].apply(lambda x: isinstance(x, str))]

# %%
# Aggregate data by stage
stage_distribution = combined_df.groupby('Stage').agg({
    'Amount($)': 'sum',
    'Stage': 'count'
}).rename(columns={'Amount($)': 'Total Funding ($)', 'Stage': 'Number of Investments'}).reset_index()

sorted_by_funding = stage_distribution.sort_values(by='Total Funding ($)', ascending=False)
top_10_funding = sorted_by_funding.head(10)

# Plot total funding by top 10 stages
plt.figure(figsize=(14, 8))
sns.barplot(x='Stage', y='Total Funding ($)', data=top_10_funding, palette='viridis')
plt.xticks(rotation=45)
plt.title('Top 10 Funding Stages by Total Funding Amount')
plt.xlabel('Funding Stage')
plt.ylabel('Total Funding ($)')
plt.show()

# %% [markdown]
# Geographical Analysis
#
# Which regions or cities in India are receiving the most start-up funding?

# %%
# Group by city and sum the funding amounts
funding_by_city = clean_combined_df.groupby('HeadQuarter')['Amount($)'].sum().reset_index()

# Identify top cities
top_cities = funding_by_city.sort_values(by='Amount($)', ascending=False).head(10)

# Plot the top cities
plt.figure(figsize=(12, 6))
plt.bar(top_cities['HeadQuarter'], top_cities['Amount($)'])
plt.title('Top Cities Receiving Start-up Funding in India (2018-2021)')
plt.xlabel('City')
plt.ylabel('Total Funding ($)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Answering Key Analytical Qestions
#
# How has the total amount of funding received by start-ups in India changed from 2018-2021?
#
# Trend Observation: From our data, we observed a consistent increase in the total funding amount year over year. There was a significant surge in 2021, indicating a strong recovery and investor confidence.
#
# Which sectors have received the most funding in each year?
#
# Top Funded Sectors:
#
# 2018: Fintech, Edtech, Healthcare 2019: Fintech, E-commerce, Healthcare 2020: Fintech, SaaS, Healthcare 2021: Fintech, Edtech, Retail
#
# Who are the top investors in the Indian start-up ecosystem from 2018-2021?
#
# Leading Investors:
#
# Sequoia Capital: Active in multiple sectors, especially in early-stage investments. Accel Partners: Known for significant investments in Fintech and E-commerce. Tiger Global: Major player in large funding rounds, focusing on later-stage start-ups. Blume Ventures: Focusing on seed and early-stage funding across diverse sectors.
#
# Which regions or cities in India are receiving the most start-up funding?
#
# Top Funded Cities:
#
# Bangalore: Dominates with significant funding across various sectors. Mumbai: Strong presence in Fintech and E-commerce. Delhi: Focus on Healthcare and Edtech. Chennai and Hyderabad: Emerging hubs with growing funding activities.
#
# What is the distribution of investment amounts across different stages of funding?
#
# Investment Stage Breakdown:
#
# Seed Stage Series A Series B Pre Series A Series C Series D

# %% [markdown]
# # Key Findings and Insights: What the Data Tells Us

# %% [markdown]
# 1.Funding Trends Over the Years We found that total funding has steadily increased from 2018 to 2021, with a notable spike in 2021. This surge could be attributed to the growing investor confidence in Indian start-ups and a favorable economic climate.
#
# 2.Sector-Wise Funding Insights Fintech emerged as the top sector, receiving the lion’s share of funding, especially in 2021. This trend underscores the rapid digitization and financial inclusion efforts in India.
#
# 3.Top Investors Our analysis highlighted key investors who have been actively fueling the start-up ecosystem. Names like Sequoia Capital and Accel Ventures frequently popped up, showcasing their role in shaping the industry.
#
# 4.Regional Funding Trends Cities like Bangalore, Mumbai, and Delhi were the top contenders in terms of funding. This reflects their status as major start-up hubs in India.
#
# 5.Funding Stages Interestingly, we found that most investments were concentrated in the Seed and Series A stages, indicating a healthy interest in early-stage start-ups with high growth potential.
